# %% [markdown]
# # Classification : 2 Class

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 학습곡선 함수

# %%
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.3.csv"
data = pd.read_csv(path)
data.drop(['Age_scale1', 'AgeGroup', 'SibSp','Parch' ], axis = 1, inplace = True)
data.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked  Family
# 0         0       3    male  22.0   7.2500        S       2
# 1         1       1  female  38.0  71.2833        C       2
# 2         1       3  female  26.0   7.9250        S       1
# 3         1       1  female  35.0  53.1000        S       2
# 4         0       3    male  35.0   8.0500        S       1

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# Sex, Age, Fare 만 이용하여 Survived 를 예측하는 모델을 만들어 봅시다.

# %% [markdown]
# ### (1) 데이터 준비

# %%
target = 'Survived'
features = ['Sex', 'Age', 'Fare']
x = data.loc[:, features]
y = data.loc[:, target]

# %% [markdown]
# ### (2) 가변수화

# %%
x = pd.get_dummies(x, columns = ['Sex'], drop_first = True)
x.head()
# Out:
#     Age     Fare  Sex_male
# 0  22.0   7.2500         1
# 1  38.0  71.2833         0
# 2  26.0   7.9250         0
# 3  35.0  53.1000         0
# 4  35.0   8.0500         1

# %% [markdown]
# ### (3) 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 20)

# %% [markdown]
# ### (4) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.딥러닝1: 3개 feature

# %% [markdown]
# ### (1) 모델설계

# %%
nfeatures = x_train.shape[1]
nfeatures
# Out:
# 3

# %%
# 메모리 정리
clear_session()

# Sequential 모델 만들기
model = Sequential( Dense( 1 , input_shape = (nfeatures ,), activation= 'sigmoid') )

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (2) compile + 학습

# %%
model.compile(optimizer = Adam(lr=0.01), loss = 'binary_crossentropy')

history = model.fit(x_train, y_train, 
                    epochs = 50, validation_split=0.2).history
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/50
# 16/16 [==============================] - 1s 15ms/step - loss: 0.9958 - val_loss: 0.9468
# Epoch 2/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.8993 - val_loss: 0.8603
# Epoch 3/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.8297 - val_loss: 0.7995
# Epoch 4/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.7813 - val_loss: 0.7599
# Epoch 5/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.7509 - val_loss: 0.7326
# Epoch 6/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.7314 - val_loss: 0.7121
# Epoch 7/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.7134 - val_loss: 0.6974
# Epoch 8/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6997 - val_loss: 0.6831
# Epoch 9/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.6865 - val_loss: 0.6706
# Epoch 10/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.6746 - val_loss: 0.6580
# Epoch 11/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6628 - val_loss: 0.6464
# Epoch 12/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.6517 - val_loss: 0.6353
# Epoch 13/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.6407 - val_loss: 0.6252
# Epoch 14/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6312 - val_loss: 0.6152
# Epoch 15/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6215 - val_loss: 0.6056
# Epoch 16/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6121 - val_loss: 0.5961
# Epoch 17/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6033 - val_loss: 0.5882
# Epoch 18/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5959 - val_loss: 0.5803
# Epoch 19/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5894 - val_loss: 0.5737
# Epoch 20/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5815 - val_loss: 0.5659
# Epoch 21/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5746 - val_loss: 0.5602
# Epoch 22/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5689 - val_loss: 0.5541
# Epoch 23/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5634 - val_loss: 0.5483
# Epoch 24/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5580 - val_loss: 0.5435
# Epoch 25/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5535 - val_loss: 0.5384
# Epoch 26/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5486 - val_loss: 0.5346
# Epoch 27/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5447 - val_loss: 0.5309
# Epoch 28/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5408 - val_loss: 0.5269
# Epoch 29/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5373 - val_loss: 0.5235
# Epoch 30/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5344 - val_loss: 0.5198
# Epoch 31/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5310 - val_loss: 0.5173
# Epoch 32/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5283 - val_loss: 0.5150
# Epoch 33/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5261 - val_loss: 0.5122
# Epoch 34/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5235 - val_loss: 0.5098
# Epoch 35/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5211 - val_loss: 0.5076
# Epoch 36/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5194 - val_loss: 0.5056
# Epoch 37/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5173 - val_loss: 0.5046
# Epoch 38/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5156 - val_loss: 0.5027
# Epoch 39/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5141 - val_loss: 0.5005
# Epoch 40/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5126 - val_loss: 0.4997
# Epoch 41/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5115 - val_loss: 0.4979
# Epoch 42/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5099 - val_loss: 0.4971
# Epoch 43/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5087 - val_loss: 0.4965
# Epoch 44/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5076 - val_loss: 0.4955
# Epoch 45/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5067 - val_loss: 0.4939
# Epoch 46/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5057 - val_loss: 0.4935
# Epoch 47/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5047 - val_loss: 0.4925
# Epoch 48/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5041 - val_loss: 0.4921
# Epoch 49/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5031 - val_loss: 0.4913
# Epoch 50/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5025 - val_loss: 0.4901

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# ### (3) 예측 및 검증

# %%
pred = model.predict(x_val)

# activation이 sigmoid --> 0 ~ 1 사이의 확률값.
# 그러므로 cut-off value(보통 0.5)를 기준으로 잘라서 0과 1로 만들어 준다.
pred = np.where(pred >= .5, 1, 0)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
print(classification_report(y_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       170
#            1       0.71      0.68      0.69        98
#
#     accuracy                           0.78       268
#    macro avg       0.76      0.76      0.76       268
# weighted avg       0.78      0.78      0.78       268

# %% [markdown]
# ## 4.딥러닝2 : 전체 feature
# * 이제 전체 데이터를 가지고 모델링을 시도해 보겠습니다.

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 준비

# %%
target = 'Survived'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# * 가변수화

# %%
cat_cols = ['Pclass','Sex', 'Embarked']
x = pd.get_dummies(x, columns = cat_cols, drop_first = True)

# %% [markdown]
# * 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
n = x_train.shape[1]
n
# Out:
# 8

# %%
# 메모리 정리
clear_session()

# Sequential 모델
model = Sequential( Dense( 1, input_shape = (n, ), activation = 'sigmoid'))

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * compile + 학습

# %%
model.compile(optimizer = Adam(learning_rate = 0.01), loss = 'binary_crossentropy')
history = model.fit(x_train, y_train, epochs = 50, validation_split=.2).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 13ms/step - loss: 0.4414 - val_loss: 0.4407
# Epoch 2/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4409 - val_loss: 0.4397
# Epoch 3/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4403 - val_loss: 0.4408
# Epoch 4/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4398 - val_loss: 0.4403
# Epoch 5/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4407 - val_loss: 0.4403
# Epoch 6/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4393 - val_loss: 0.4419
# Epoch 7/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4395 - val_loss: 0.4411
# Epoch 8/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4390 - val_loss: 0.4404
# Epoch 9/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4390 - val_loss: 0.4411
# Epoch 10/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4397 - val_loss: 0.4399
# Epoch 11/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4387 - val_loss: 0.4403
# Epoch 12/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4391 - val_loss: 0.4411
# Epoch 13/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4384 - val_loss: 0.4402
# Epoch 14/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4383 - val_loss: 0.4401
# Epoch 15/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4382 - val_loss: 0.4405
# Epoch 16/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4378 - val_loss: 0.4408
# Epoch 17/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4377 - val_loss: 0.4408
# Epoch 18/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4379 - val_loss: 0.4408
# Epoch 19/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4381 - val_loss: 0.4404
# Epoch 20/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4372 - val_loss: 0.4411
# Epoch 21/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4374 - val_loss: 0.4405
# Epoch 22/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4373 - val_loss: 0.4405
# Epoch 23/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4370 - val_loss: 0.4413
# Epoch 24/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4369 - val_loss: 0.4410
# Epoch 25/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4370 - val_loss: 0.4410
# Epoch 26/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4365 - val_loss: 0.4411
# Epoch 27/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4367 - val_loss: 0.4411
# Epoch 28/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4366 - val_loss: 0.4404
# Epoch 29/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4362 - val_loss: 0.4412
# Epoch 30/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4360 - val_loss: 0.4404
# Epoch 31/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4367 - val_loss: 0.4399
# Epoch 32/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4378 - val_loss: 0.4409
# Epoch 33/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4362 - val_loss: 0.4403
# Epoch 34/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4359 - val_loss: 0.4409
# Epoch 35/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4355 - val_loss: 0.4414
# Epoch 36/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4357 - val_loss: 0.4417
# Epoch 37/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4358 - val_loss: 0.4423
# Epoch 38/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4359 - val_loss: 0.4431
# Epoch 39/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4357 - val_loss: 0.4423
# Epoch 40/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4356 - val_loss: 0.4422
# Epoch 41/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4358 - val_loss: 0.4402
# Epoch 42/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4350 - val_loss: 0.4409
# Epoch 43/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4355 - val_loss: 0.4410
# Epoch 44/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4353 - val_loss: 0.4427
# Epoch 45/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4351 - val_loss: 0.4421
# Epoch 46/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4347 - val_loss: 0.4421
# Epoch 47/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4346 - val_loss: 0.4412
# Epoch 48/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4347 - val_loss: 0.4409
# Epoch 49/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4348 - val_loss: 0.4421
# Epoch 50/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4344 - val_loss: 0.4420

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# * 예측 및 검증

# %%
pred2 = model.predict(x_val)
pred2 = np.where( pred2 >= .5 , 1, 0)
print(classification_report(y_val, pred2))
# Out:
# 9/9 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82       170
#            1       0.68      0.66      0.67        98
#
#     accuracy                           0.76       268
#    macro avg       0.75      0.74      0.74       268
# weighted avg       0.76      0.76      0.76       268

# %% [markdown]
# ----

# %% [markdown]
# ## 5.딥러닝3 : hidden layer
# * 이제 레이어를 추가해 보겠습니다.

# %% [markdown]
# ### (1) 모델 설계

# %%
n = x_train.shape[1]
n
# Out:
# 8

# %%
# 메모리 정리
clear_session()

# Sequential 모델
model3 = Sequential([ Dense( 4, input_shape = (n ,), activation = 'relu'),
                      Dense( 1, activation = 'sigmoid')])

# 모델요약
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 36
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (2) compile + 학습

# %%
model3.compile( optimizer=Adam(learning_rate= 0.01), loss ='binary_crossentropy')
hist = model3.fit(x_train, y_train, epochs = 50, validation_split=.2 ).history

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(hist)

# %% [markdown]
# * 예측 및 검증

# %%
pred3 = model3.predict(x_val)
pred3 = np.where(pred3 >= 0.5, 1, 0)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
print(classification_report(y_val, pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.91      0.84       170
#            1       0.79      0.57      0.66        98
#
#     accuracy                           0.79       268
#    macro avg       0.79      0.74      0.75       268
# weighted avg       0.79      0.79      0.78       268

# %% [markdown]
# ### (3) 실습1

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | 옵션 |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 16)  | node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 1) | node, activation = 'sigmoid' |

# %%
m5 = Sequential([ Dense(16, input_shape = (n,), activation='relu'),
                 Dense(1, activation = 'sigmoid')])
m5.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 16)                144
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 161
# Trainable params: 161
# Non-trainable params: 0
# _________________________________________________________________

# %%
m5.compile(optimizer = Adam(learning_rate=.01) , loss = 'binary_crossentropy')
hist = m5.fit(x_train, y_train, epochs = 50 , validation_split= .2).history

# %%
dl_history_plot(hist)

# %%
p5 = m5.predict(x_val)
p5 = np.where( p5 >= 0.5, 1, 0)

print(classification_report(y_val, p5))
# Out:
# 9/9 [==============================] - 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84       170
#            1       0.74      0.63      0.68        98
#
#     accuracy                           0.78       268
#    macro avg       0.77      0.75      0.76       268
# weighted avg       0.78      0.78      0.78       268

# %% [markdown]
# ### (4) 실습2

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape |  옵션 |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 16) |  node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 8) |  node, activation = 'relu'  |
# | dense_2 (Dense) | (None, 1) |  node, activation = 'sigmoid'  |

# %%
m6 = Sequential([ Dense(16, input_shape = (n,), activation='relu'),
                 Dense(8, activation='relu'),
                 Dense(1, activation = 'sigmoid')])
m6.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 16)                144
#
#  dense_5 (Dense)             (None, 8)                 136
#
#  dense_6 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 289
# Trainable params: 289
# Non-trainable params: 0
# _________________________________________________________________

# %%
m6.compile(optimizer = Adam(learning_rate=.01) , loss = 'binary_crossentropy')
hist = m6.fit(x_train, y_train, epochs = 50 , validation_split= .2).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 2s 43ms/step - loss: 0.5953 - val_loss: 0.5299
# Epoch 2/50
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5191 - val_loss: 0.4800
# Epoch 3/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4740 - val_loss: 0.4668
# Epoch 4/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4541 - val_loss: 0.4417
# Epoch 5/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4416 - val_loss: 0.4328
# Epoch 6/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4317 - val_loss: 0.4231
# Epoch 7/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4257 - val_loss: 0.4119
# Epoch 8/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4250 - val_loss: 0.4155
# Epoch 9/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4153 - val_loss: 0.4064
# Epoch 10/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4155 - val_loss: 0.4146
# Epoch 11/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4164 - val_loss: 0.4127
# Epoch 12/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4040 - val_loss: 0.4013
# Epoch 13/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4034 - val_loss: 0.4041
# Epoch 14/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3980 - val_loss: 0.3993
# Epoch 15/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3992 - val_loss: 0.4200
# Epoch 16/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4028 - val_loss: 0.4103
# Epoch 17/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4050 - val_loss: 0.3943
# Epoch 18/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3910 - val_loss: 0.4058
# Epoch 19/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3931 - val_loss: 0.4034
# Epoch 20/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3892 - val_loss: 0.4010
# Epoch 21/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3927 - val_loss: 0.4136
# Epoch 22/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3965 - val_loss: 0.4103
# Epoch 23/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3947 - val_loss: 0.4133
# Epoch 24/50
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3978 - val_loss: 0.4077
# Epoch 25/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3860 - val_loss: 0.4156
# Epoch 26/50
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3887 - val_loss: 0.4095
# Epoch 27/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3868 - val_loss: 0.4185
# Epoch 28/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3832 - val_loss: 0.4062
# Epoch 29/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3828 - val_loss: 0.4111
# Epoch 30/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3855 - val_loss: 0.4100
# Epoch 31/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3791 - val_loss: 0.4062
# Epoch 32/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3769 - val_loss: 0.4207
# Epoch 33/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3827 - val_loss: 0.4159
# Epoch 34/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3998 - val_loss: 0.4193
# Epoch 35/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3863 - val_loss: 0.4617
# Epoch 36/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3830 - val_loss: 0.4082
# Epoch 37/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3817 - val_loss: 0.4185
# Epoch 38/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3756 - val_loss: 0.4153
# Epoch 39/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3800 - val_loss: 0.4202
# Epoch 40/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3813 - val_loss: 0.4088
# Epoch 41/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3717 - val_loss: 0.4181
# Epoch 42/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3765 - val_loss: 0.4109
# Epoch 43/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3847 - val_loss: 0.4532
# Epoch 44/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3774 - val_loss: 0.4125
# Epoch 45/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3763 - val_loss: 0.4022
# Epoch 46/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3828 - val_loss: 0.4327
# Epoch 47/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3824 - val_loss: 0.4165
# Epoch 48/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3709 - val_loss: 0.4248
# Epoch 49/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3690 - val_loss: 0.4369
# Epoch 50/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3781 - val_loss: 0.4144

# %%
dl_history_plot(hist)

# %%
p6 = m6.predict(x_val)
p6 = np.where( p6 >= 0.5, 1, 0)

print(classification_report(y_val, p6))
# Out:
# 9/9 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.83       170
#            1       0.74      0.61      0.67        98
#
#     accuracy                           0.78       268
#    macro avg       0.77      0.74      0.75       268
# weighted avg       0.78      0.78      0.77       268

# %% [markdown]
# ### (5) 실습3

# %% [markdown]
# * 이번에는 여러분이 원하는 대로 설계하고, 학습해 봅시다.
