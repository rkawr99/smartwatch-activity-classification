# %% [markdown]
# # Day2: **1:1 문의 내용 기반 문의유형 자동 분류 모델링**

# %% [markdown]
# * [미션0] 오늘의 목표
# * [미션1] 개발환경 설정하기
# * [미션2] 코드 유형 문의내용 분리하기
# * [미션3] 워드클라우드 생성하기1
# * [미션4] 데이터 전처리하기
# * [미션5] 워드클라우드 생성하기2
# * [미션6] 교육 개선점 찾기
# * <도전미션> 문의유형 별 워드클라우드 생성 및 분야별 개선점 찾기

# %% [markdown]
# ----------

# %% [markdown]
# ### <span style="color:green;background-color:#fff5b1">[미션0] 오늘의 목표: </span><span style="color:red;background-color:#fff5b1">중요 키워드 시각화 및 교육 개선 인사이트 도출</span>

# %% [markdown]
# * 1:1 질문들 속에서 중요한 키워드를 찾아 교육에 반영하는 일은 교육 개발에 중요한 일 입니다.
# * 그러나 수많은 설문조사에서 중요한 키워드를 수기로 찾아내는 일은 많은 리소스와 시간이 필요 합니다.
# * 오늘의 미션을 통해 자연어 데이터를 시각화하여 그 속에서 중요한 키워드를 도출하고 어느 부분에 개선이 필요한지 인사이트를 도출해 주세요.

# %% [markdown]
# ----------

# %% [markdown]
# ### <span style="color:green;background-color:#fff5b1">[미션1] 개발환경 설정하기</span>

# %% [markdown]
# 자연어 데이터에서 중요 키워드를 도출하기 위해 개발환경을 설정하고 데이터를 정리 합니다.
# * 필요 라이브러리를 호출하기
# * 데이터 파일 불러오기
# * 데이터셋 합치기
# * 불필요 컬럼 삭제하기
# * '\n'(줄바꿈문자 또는 개행문자) 삭제하기

# %%
# 필요 라이브러리를 호출하기
## 필요한 라이브러리는 추가로 불러 오세요.
## 프로젝트를 진행하며 필요한 라이브러리는 추가로 설치 하세요.

import pandas as pd    # pandas 데이터프레임을 생성/편집하기 위해 사용 합니다.
import numpy as np    # numpy 행렬을 생성/편집하기 위해 사용 합니다.
import matplotlib.pyplot as plt    # 데이터를 각종 차트로 시각화하기 위해 사용 합니다.
from wordcloud import WordCloud    # 워드 클라우드를 생성하기 위해 사용 합니다.
from collections import Counter    # 단어의 수를 카운트하기 위해 사용 합니다.
import re    # 정규표현식을 사용하기 위해 사용 합니다.
from PIL import Image # 이미지를 로드 할때 사용합니다.


font_path = 'malgun.ttf' # 워드클라우드 한글 폰트 사용


plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
# 데이터 파일 불러오기
## 'QnA_train_data.csv' 파일 불러와 train_df 변수에 할당 합니다.
## 'QnA_test_data.csv' 파일 불러와 test_df 변수에 할당 합니다.

train_df = 
test_df =

# %%
# 데이터셋 합치기
## train_df 데이터와 test_df 데이터를 합쳐서 하나의 데이터셋으로 만들어 줍니다.
## 합쳐진 데이터를 data 변수에 할당하고 인덱스를 reset 합니다.

data =
# Out:
#           트랙     지역                                               문의내용    문의유형
# 0     DX컨설턴트    수도권  inplace= True 를 사용하는 기준이 존재하는 것인지, 아니면 함수나 메소드...     코드2
# 1      AI개발자    수도권         참조파일2에 대한 (yolo부분) 답안 파일이 올라오지 않은 것 같습니다!   시스템 운영
# 2      AI개발자  전남/전북  AICE 시험 관련하여 이렇게 1대1로 질문하는게 맞나요..?\n맞다면, 질문드립니...  시스템 운영
# 3     DX컨설턴트  충남/충북  예제는 잘 작동한 것 같은데 채점하니 케이스 1만 성공하고 나머지가 fail이 떠 ...     코드1
# 4     DX컨설턴트  대구/경북  제주관광공사를 대상으로 관광지 순환 버스 솔루션을 도입하여\n운전을 못하는 관광객 ...      이론
# ...      ...    ...                                                ...     ...
# 3785  DX컨설턴트  대구/경북  어디가 잘못되었는지 모르겠어요ㅜㅜ\n\nN = list(map(int, input(...     코드1
# 3786  DX컨설턴트    수도권  실습교안 102 쪽 진행중인데 이전단계에서 실습 교안대로 진행했는데 사진처럼 나옵니...       웹
# 3787   AI개발자  충남/충북                                 ubuntu 파일 이 안 열립니다       웹
# 3788  DX컨설턴트    수도권  4. 데이터 분석 항복에 있는 6개의 문제에 대한 코드와 그래프 확인 부탁드립니다....     코드2
# 3789   AI개발자  충남/충북  img_list는 train의 jpg 리스트\n\nfor i in img_list:...     코드2
#
# [3790 rows x 4 columns]

# %%
# 불필요 컬럼 삭제하기
## drop 함수를 사용하여 필요없는 컬럼을 삭제 합니다.
## 삭제할 컬럼: ['트랙', '지역']
# Out:
#                                                    문의내용    문의유형
# 0     inplace= True 를 사용하는 기준이 존재하는 것인지, 아니면 함수나 메소드...     코드2
# 1            참조파일2에 대한 (yolo부분) 답안 파일이 올라오지 않은 것 같습니다!   시스템 운영
# 2     AICE 시험 관련하여 이렇게 1대1로 질문하는게 맞나요..?\n맞다면, 질문드립니...  시스템 운영
# 3     예제는 잘 작동한 것 같은데 채점하니 케이스 1만 성공하고 나머지가 fail이 떠 ...     코드1
# 4     제주관광공사를 대상으로 관광지 순환 버스 솔루션을 도입하여\n운전을 못하는 관광객 ...      이론
# ...                                                 ...     ...
# 3785  어디가 잘못되었는지 모르겠어요ㅜㅜ\n\nN = list(map(int, input(...     코드1
# 3786  실습교안 102 쪽 진행중인데 이전단계에서 실습 교안대로 진행했는데 사진처럼 나옵니...       웹
# 3787                                 ubuntu 파일 이 안 열립니다       웹
# 3788  4. 데이터 분석 항복에 있는 6개의 문제에 대한 코드와 그래프 확인 부탁드립니다....     코드2
# 3789  img_list는 train의 jpg 리스트\n\nfor i in img_list:...     코드2
#
# [3790 rows x 2 columns]

# %%
# '\n'(줄바꿈문자 또는 개행문자) 삭제하기
## 줄바꿈문자는 워드클라우드에서 에러를 일으켜 삭제 해야 합니다.
## 반복문을 사용하여 data['문의내용']의 각 열에서 '\n'을 ' '으로 변경 한 후
## 다시 data['문의내용']에 넣어 줍니다.

for i in        
        data['문의내용'].loc[i] = 

data
# Out:
#                                                    문의내용    문의유형
# 0     inplace= True 를 사용하는 기준이 존재하는 것인지, 아니면 함수나 메소드...     코드2
# 1            참조파일2에 대한 (yolo부분) 답안 파일이 올라오지 않은 것 같습니다!   시스템 운영
# 2     AICE 시험 관련하여 이렇게 1대1로 질문하는게 맞나요..? 맞다면, 질문드립니다...  시스템 운영
# 3     예제는 잘 작동한 것 같은데 채점하니 케이스 1만 성공하고 나머지가 fail이 떠 ...     코드1
# 4     제주관광공사를 대상으로 관광지 순환 버스 솔루션을 도입하여 운전을 못하는 관광객 유...      이론
# ...                                                 ...     ...
# 3785  어디가 잘못되었는지 모르겠어요ㅜㅜ  N = list(map(int, input()....     코드1
# 3786  실습교안 102 쪽 진행중인데 이전단계에서 실습 교안대로 진행했는데 사진처럼 나옵니...       웹
# 3787                                 ubuntu 파일 이 안 열립니다       웹
# 3788  4. 데이터 분석 항복에 있는 6개의 문제에 대한 코드와 그래프 확인 부탁드립니다....     코드2
# 3789  img_list는 train의 jpg 리스트  for i in img_list:  ...     코드2
#
# [3790 rows x 2 columns]

# %% [markdown]
# ### <span style="color:green;background-color:#fff5b1"> [미션2] 코드 유형 문의내용 분리하기</span>

# %% [markdown]
# 가장 질문이 많은 코드1과 코드2의 내용을 워드클라우드로 시각화하기위해 코드 데이터만 따로 분리 합니다.
#
# * data['문의유형'] 이 코드1, 코드2 데이터 분리하기
# * 단어 리스트 생성하기
# * 전체 단어 빈도수 카운트하기

# %%
# data['문의유형'] 이 코드1, 코드2 데이터 분리하기
## data['문의유형'] 열의 값이(유형이) 코드1, 코드2 인 행의 data['문의내용'] 을 담을 type_questions 변수를 pd.Series 타입으로 생성하고 초기화 합니다.
## 반복문을 사용하여 data['문의유형'] 열의 값이(유형이) '코드1', '코드2' 인 값을 type_questions 변수에 할당 합니다.

type_questions = pd.Series()

for i in data.index:




type_questions
# Out:
# C:\Users\qicha\AppData\Local\Temp\ipykernel_5632\1467813994.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   type_questions = pd.Series()
# 0       inplace= True 를 사용하는 기준이 존재하는 것인지, 아니면 함수나 메소드...
# 3       예제는 잘 작동한 것 같은데 채점하니 케이스 1만 성공하고 나머지가 fail이 떠 ...
# 9       실습 내용중 오존 변수의 결측치를 다른 값으로 바꿔서 처리할려고 했습니다, targ...
# 15      오존 이변량 분석 중입니다 spst.pearsonr(bike['ozone'],bik...
# 20      seoul_drop=seoul_moving.loc[(seoul_moving['도착시...
#                               ...
# 3782    3번 문제에서 - 외국인 정보가 1981 ~ 1984년이 누락되어 결측치가 발생할 ...
# 3783    bins = [0,30, 80, 150, 160]         trindata['...
# 3785    어디가 잘못되었는지 모르겠어요ㅜㅜ  N = list(map(int, input()....
# 3788    4. 데이터 분석 항복에 있는 6개의 문제에 대한 코드와 그래프 확인 부탁드립니다....
# 3789    img_list는 train의 jpg 리스트  for i in img_list:  ...
# Length: 1611, dtype: object

# %%
# 단어 리스트 생성하기
## 각 문의에서 단어를 분리해서 담을 word_list 변수를 리스트 타입으로 생성 합니다.
## 반복문을 사용하여 type_questions 데이터의 각 행의 문장이 단어의 모음이 되도록 띄어쓰기(' ') 기준으로 split 합니다.
## 각 행에서 분리된 단어들을 다시 반복문을 이용해 word_list 변수에 단어를 한개씩 append 해 줍니다.
## 단어별 빈도수 체크를 위해 최종 word_list 의 차원이 1차원 인지 확인 합니다.
## [TIP] 이중 반복문을 사용하면 쉽게 단어를 분리하고 모을 수 있습니다.


word_list = []
for sent in type_questions:





word_list
# Out:
# ['inplace=',
#  'True',
#  '를',
#  '사용하는',
#  '기준이',
#  '존재하는',
#  '것인지,',
#  '아니면',
#  '함수나',
#  '메소드에',
#  '따라',
#  '외워야하는',
#  '것인지',
#  '궁금합니다.',
#  '',
#  '또한',
#  'inplace를',
#  '사용해야',
#  '하는',
#  '대표적인',
#  '함수나',
#  '메소드들이',
#  '궁금합니다.',
#  '예제는',
#  '잘',
#  '작동한',
#  '것',
#  '같은데',
#  '채점하니',
#  '케이스',
#  '1만',
#  '성공하고',
#  '나머지가',
#  'fail이',
#  '떠',
#  '실패했습니다.',
#  '제가',
#  '어디서',
#  '틀렸는지',
#  '잘',
#  '모르겠습니다.',
#  '아니면',
#  '제가',
#  '한',
#  '방법',
#  '말고',
#  '더',
#  '좋은',
#  '방법이',
#  '있을까요?',
#  '',
#  '실습',
#  '내용중',
#  '오존',
#  '변수의',
#  '결측치를',
#  '다른',
#  '값으로',
#  '바꿔서',
#  '처리할려고',
#  '했습니다,',
#  'target1',
#  '=',
#  "'ozone'",
#  'temp',
#  '=',
#  'tr_abc[target1]',
#  '',
#  '',
#  'temp=temp.fillna(0.000)',
#  'temp.unique()',
#  '',
#  '위와',
#  '같은',
#  '코드로',
#  '결측치를',
#  '바꿨고',
#  '유니크',
#  '메소드에서',
#  '정상적으로',
#  '0으로',
#  '표시되면서',
#  '바뀌는',
#  '것을',
#  '확인했습니다.',
#  '',
#  '그러나',
#  '이후',
#  '다시',
#  '유니크',
#  '메소드를',
#  '실행했더니',
#  '결측치가',
#  '0으로',
#  '바뀌지',
#  '않고',
#  'nan',
#  '값으로',
#  '표기되어서',
#  '나와',
#  '있습니다.',
#  '어디서',
#  '잘못된건지',
#  '알려주실',
#  '수',
#  '있을까요?',
#  '오존',
#  '이변량',
#  '분석',
#  '중입니다',
#  "spst.pearsonr(bike['ozone'],bike['count'])",
#  '이렇게',
#  '코드',
#  '쳤는데',
#  '',
#  'array',
#  'must',
#  'not',
#  'contain',
#  'infs',
#  'or',
#  'NaNs',
#  '오류',
#  '문구가',
#  '뜨네요ㅜ',
#  "seoul_drop=seoul_moving.loc[(seoul_moving['도착시간']",
#  '=',
#  '0)]',
#  'seoul_drop',
#  'seoul_moving.drop(seoul_drop,',
#  'inplace',
#  '=',
#  'True)',
#  '',
#  '위와',
#  '같은',
#  '코드에서',
#  '에러가',
#  '나옵니다.',
#  'KeyError:',
#  '"[\'대상연월\'',
#  "'요일'",
#  "'도착시간'",
#  "'출발",
#  '시군구',
#  "코드'",
#  "'도착",
#  '시군구',
#  "코드'",
#  "'성별'",
#  "'나이'",
#  "'이동유형'",
#  "'평균",
#  '이동',
#  "시간(분)'\\n",
#  "'이동인구(합)']",
#  'not',
#  'found',
#  'in',
#  'axis"',
#  '이런',
#  '에러가',
#  '나왔는데',
#  '어떤',
#  '점이',
#  '문제인지',
#  '이해가',
#  '안가서',
#  '설명해',
#  '주시면',
#  '감사하겠습니다',
#  'plt.barh(df_feature,rf.feature_importances_)',
#  '',
#  '입력해도',
#  '중요도가',
#  '안나오는데',
#  '어디를',
#  '고치면',
#  '되는지',
#  '알',
#  '수',
#  '있을까요?',
#  'ERROR:',
#  'Unexpected',
#  'Column:',
#  '',
#  "'Result_v1'",
#  '(Line',
#  '1,',
#  'Column',
#  '13)',
#  '',
#  '해당',
#  '에러의',
#  '원인을',
#  '알려주세요',
#  'while',
#  'True:',
#  '',
#  '',
#  '',
#  '',
#  'red',
#  '=',
#  "int(input('빨간색",
#  '접시',
#  '&gt;&gt;',
#  "'))*1000",
#  '',
#  '',
#  '',
#  '',
#  'blue',
#  '=',
#  "int(input('파란색",
#  '접시',
#  '&gt;&gt;',
#  "'))*1500",
#  '',
#  '',
#  '',
#  '',
#  'green',
#  '=',
#  "int(input('초록색",
#  '접시',
#  '&gt;&gt;',
#  "'))*2000",
#  '',
#  '',
#  '',
#  '',
#  'yellow',
#  '=',
#  "int(input('노란색",
#  '접시',
#  '&gt;&gt;',
#  "'))*3000",
#  '',
#  '',
#  '',
#  '',
#  'black',
#  '=',
#  "int(input('검은색",
#  '접시',
#  '&gt;&gt;',
#  "'))*5000",
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'if',
#  'red==0',
#  ':',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'break',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "print('",
#  '치훈이가',
#  '내야',
#  '하는',
#  '초밥값(원)',
#  ':',
#  "{}'.format(red",
#  '+',
#  'blue',
#  '+',
#  'green',
#  '+',
#  'yellow',
#  '+',
#  'black))',
#  "print('프로그램이",
#  "종료되었습니다.')",
#  '',
#  '코드는',
#  '이렇게',
#  '입력했습니다.',
#  '예제출력1,2에',
#  '대한',
#  '답이',
#  '맞게',
#  '나왔다고',
#  '생각하는데(47,000원,',
#  '49,000원)',
#  'fail이라고',
#  '떠서요..',
#  '혹시',
#  '어디가',
#  '문제일지',
#  '도움',
#  '받을',
#  '수',
#  '있을까요?ㅠ.ㅠ',
#  '케이스0~6',
#  'fail',
#  '이라고',
#  '뜹니다.',
#  '.',
#  '교안에',
#  '나와있는대로',
#  '평균',
#  '시속',
#  '변수',
#  "'PerHour'를",
#  '사진과',
#  '같이',
#  '생성했습니다.',
#  '그런데',
#  '문제4-2번',
#  '조건이',
#  'PerHour',
#  '기준으로',
#  '130km/h',
#  '초과의',
#  '수치는',
#  '제거하라는',
#  '건데,',
#  '제가',
#  '구한',
#  'PerHour값의',
#  'MAX는',
#  '1.388',
#  '정도라',
#  '잘못된',
#  '것',
#  '같습니다.',
#  '',
#  '무엇을',
#  '잘못',
#  '계산한건지',
#  '궁금합니다..',
#  'temp',
#  '=',
#  "titanic.loc[titanic['Age'].notnull()]",
#  '',
#  'E1',
#  '=',
#  "temp.loc[temp['Embarked']",
#  "=='S'",
#  ',',
#  "'Age']",
#  'E2',
#  '=',
#  "temp.loc[temp['Embarked']",
#  "=='C'",
#  ',',
#  "'Age']",
#  'E3',
#  '=',
#  "temp.loc[temp['Embarked']",
#  "=='Q'",
#  ',',
#  "'Age']",
#  '',
#  'spst.f_oneway(E1,E2,E3)',
#  '',
#  '이런',
#  '식으로',
#  '결측치가',
#  '있는',
#  '경우',
#  '결측치를',
#  '제거하고',
#  '아노바를',
#  '돌린다고',
#  '배웠는데,',
#  '이때',
#  '결측치',
#  '제거는',
#  'y(target)이',
#  '되는',
#  '열(위의',
#  '경우',
#  'age)을',
#  '대상으로',
#  '지우는게',
#  '맞을까요?',
#  '',
#  '안녕하세요',
#  '튜터님..솔루션',
#  '2번',
#  '파일',
#  '모델링',
#  '했을때',
#  '에러가',
#  '발생합니다.',
#  '어떻게',
#  '해결할까요,,????',
#  '안녕하세요',
#  '3400.',
#  '가우스와',
#  '정다각형',
#  '문제',
#  '질문드립니다!',
#  '정수',
#  'k를',
#  '받고',
#  '각',
#  '페르마',
#  '소수와',
#  '2의',
#  '제곱수를',
#  '리스트로',
#  '받아',
#  '리스트',
#  'x에',
#  '가능한',
#  '정다각형을',
#  '넣었습니다.',
#  '이후',
#  '입력받은',
#  'k가',
#  '리스트',
#  'x에',
#  '있으면',
#  '결과값을',
#  'YES,',
#  '그렇지',
#  '않으면',
#  'NO로',
#  '출력하게',
#  '했습니다.',
#  '',
#  '그런데',
#  '케이스',
#  '2개가',
#  '실패가',
#  '뜹니다..',
#  '뭐가',
#  '원인인가요?',
#  '감사합니다!',
#  '',
#  '&gt;&gt;코드',
#  'k',
#  '=',
#  'int(input())',
#  'frm',
#  '=',
#  '[1,',
#  '3,5,17,257,65537]',
#  'frm_x',
#  '=[',
#  '3,5,17,257,65537]',
#  'two',
#  '=',
#  '[]',
#  'x=[]',
#  '',
#  'for',
#  'i',
#  'in',
#  'range(63+1):',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  '+=',
#  '[2**i]',
#  '',
#  'for',
#  'i',
#  'in',
#  'two:',
#  '',
#  '',
#  '',
#  '',
#  'for',
#  'j',
#  'in',
#  'frm_x:',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'for',
#  't',
#  'in',
#  'frm:',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'if',
#  'j!=t:',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'x',
#  '+=[j*t*i]',
#  '',
#  'x',
#  '=',
#  'list(set(x))',
#  '',
#  'if',
#  'k',
#  'in',
#  'x:',
#  '',
#  '',
#  '',
#  '',
#  'print("YES")',
#  'else:',
#  '',
#  '',
#  '',
#  '',
#  'print("NO")',
#  '',
#  '',
#  '&gt;채점결과',
#  '#',
#  '케이스',
#  '0\tPassed\t2.15',
#  's\t',
#  '#',
#  '케이스',
#  '1\tPassed\t1.768',
#  's\t',
#  '#',
#  '케이스',
#  '2\tFailed\t1.994',
#  's\t',
#  '#',
#  '케이스',
#  '3\tPassed\t1.844',
#  's\t',
#  '#',
#  '케이스',
#  '4\tPassed\t1.885',
#  's\t',
#  '#',
#  '케이스',
#  '5\tPassed\t1.711',
#  's\t',
#  '#',
#  '케이스',
#  '6\tFailed\t1.621',
#  's',
#  '',
#  '날짜를',
#  '주말,',
#  '평일로',
#  '나누고',
#  '싶습니다.',
#  '기존의',
#  'week_s열에서',
#  'Sat과',
#  'Sun가',
#  '포함된',
#  '행에는',
#  '1',
#  '기존의',
#  'week_s열에',
#  '나머지는',
#  '0으로',
#  '표시되는',
#  '열을',
#  '추가하고싶은데',
#  '',
#  '어떻게',
#  '해야할까요?',
#  '',
#  '',
#  "bike_s['주말']",
#  '=',
#  "bike_s.loc[bike_s['week_s']",
#  '==',
#  "'Sat',",
#  "'1']",
#  '',
#  "bike_s['주말']",
#  '=',
#  "bike_s[bike_s['week_s']",
#  '==',
#  "'Sun',",
#  "'0']",
#  'bike_s',
#  'from',
#  'sklearn.preprocessing',
#  'import',
#  'MinMaxScaler',
#  'scaler',
#  '=',
#  'MinMaxScaler()',
#  'scaler.fit(df_total)',
#  '',
#  '이렇게',
#  '작성하였는데',
#  '',
#  'ValueError:',
#  'could',
#  'not',
#  'convert',
#  'string',
#  'to',
#  'float:',
#  "'router-84875df7fc-b5nxc-7-20255166-0'",
#  '이런',
#  '에러가',
#  '뜨는데요',
#  'string이',
#  '있어서',
#  '그런',
#  '것',
#  '같은데',
#  '뭔가',
#  '변환을',
#  '해줘야',
#  '하는건가요?',
#  'C:\\Users\\User\\AppData\\Roaming\\Python\\Python38\\site-packages\\sklearn\\base.py:493:',
#  'FutureWarning:',
#  'The',
#  'feature',
#  'names',
#  'should',
#  'match',
#  'those',
#  'that',
#  'were',
#  'passed',
#  'during',
#  'fit.',
#  'Starting',
#  'version',
#  '1.2,',
#  'an',
#  'error',
#  'will',
#  'be',
#  'raised.',
#  'Feature',
#  'names',
#  'unseen',
#  'at',
#  'fit',
#  'time:',
#  '-',
#  'Unnamed:',
#  '0',
#  '-',
#  "html_num_tags('applet')",
#  '-',
#  'url_chinese_present',
#  '-',
#  'url_domain_len',
#  '-',
#  'url_path_len',
#  '',
#  '',
#  '',
#  'warnings.warn(message,',
#  'FutureWarning)',
#  '---------------------------------------------------------------------------',
#  'ValueError',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Traceback',
#  '(most',
#  'recent',
#  'call',
#  'last)',
#  '',
#  'in',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  'test_z',
#  '=',
#  'pd.read_csv("test_dataset_v01.csv")',
#  '----&gt;',
#  '2',
#  'pred',
#  '=',
#  'model_dt.predict(test_z)',
#  '',
#  '~\\AppData\\Roaming\\Python\\Python38\\site-packages\\sklearn\\tree\\_classes.py',
#  'in',
#  'predict(self,',
#  'X,',
#  'check_input)',
#  '',
#  '',
#  '',
#  '',
#  '503',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '"""',
#  '',
#  '',
#  '',
#  '',
#  '504',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'check_is_fitted(self)',
#  '--&gt;',
#  '505',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'X',
#  '=',
#  'self._validate_X_predict(X,',
#  'check_input)',
#  '',
#  '',
#  '',
#  '',
#  '506',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'proba',
#  '=',
#  'self.tree_.predict(X)',
#  '',
#  '',
#  '',
#  '',
#  '507',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'n_samples',
#  '=',
#  'X.shape[0]',
#  '',
#  '~\\AppData\\Roaming\\Python\\Python38\\site-packages\\sklearn\\tree\\_classes.py',
#  'in',
#  '_validate_X_predict(self,',
#  'X,',
#  'check_input)',
#  '',
#  '',
#  '',
#  '',
#  '469',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '"""Validate',
#  'the',
#  'training',
#  'data',
#  'on',
#  'predict',
#  '(probabilities)."""',
#  '',
#  '',
#  '',
#  '',
#  '470',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'if',
#  'check_input:',
#  '--&gt;',
#  '471',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'X',
#  '=',
#  'self._validate_data(X,',
#  'dtype=DTYPE,',
#  'accept_sparse="csr",',
#  'reset=False)',
#  '',
#  '',
#  '',
#  '',
#  '472',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'if',
#  'issparse(X)',
#  'and',
#  '(',
#  '',
#  '',
#  '',
#  '',
#  '473',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'X.indices.dtype',
#  '!=',
#  'np.intc',
#  'or',
#  'X.indptr.dtype',
#  '!=',
#  'np.intc',
#  '',
#  '~\\AppData\\Roaming\\Python\\Python38\\site-packages\\sklearn\\base.py',
#  'in',
#  '_validate_data(self,',
#  'X,',
#  'y,',
#  'reset,',
#  'validate_separately,',
#  '**check_params)',
#  '',
#  '',
#  '',
#  '',
#  '575',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'raise',
#  'ValueError("Validation',
#  'should',
#  'be',
#  'done',
#  'on',
#  'X,',
#  'y',
#  'or',
#  'both.")',
#  '',
#  '',
#  '',
#  '',
#  '576',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ...]

# %%
# 전체 단어 빈도수 카운트하기
## Counter 함수를 사용하여 word_list 변수에 포함된 각 단어의 빈도수를 산출하여 word_count에 할당 합니다.

word_count =

# %% [markdown]
# ### <span style="color:green;background-color:#fff5b1"> [미션3]워드클라우드 생성하기1</span>

# %% [markdown]
# 1:1 문의에서 반복되는 키워드를 파악하기 위하여 워드클라우드를 생성하고 단어별 빈도수를 체크 합니다.<br>
# 모든 데이터를 한 문단으로 합쳐서 워드클라우드를 생성 할 수도 있지만, 미프4-1차 에서는 단어별 빈도수를 활용하여 워드클라우드를 생성 합니다.<br>
# 생성된 워드클라우드에서 교육생들이 어려워 하는 부분이 무엇인지 생각해 보세요.
# * 워드클라우드 생성하기
# * 단어별 빈도수로 정렬하기

# %%
# 워드클라우드 생성하기
## 각 단어의 빈도수가 저장되어 있는 word_count 변수로 워드클라우드를 생성합니다.
## 높이, 넓이, 색상 등 생성하는 워드클라우드의 파라미터를 알맞게 조절 합니다.
## 워드클라우드 생성 매서드는 .generate_from_frequencies 를 사용합니다.
## [tip] 한 문단으로 워드클라우드로 만들때는 generate 매서드 사용
## [tip] 단어와 빈도수를 가지고 워드클라우드를 만들때는 generate_from_frequencies 매서드 사용



origin_cloud = WordCloud(
    
    
        ).generate_from_frequencies(word_count)




plt.axis(   )
# Out:
# (-0.5, 499.5, 499.5, -0.5)

# %%
# 단어별 빈도수로 정렬하기
## Counter 함수의 .most_common 매서드를 사용하여 word_count에 저장된 단어의 빈도수를 내림차순으로 출력 합니다.
## 가장 많이 사용된 단어들이 무엇인지 확인 합니다.
# Out:
# [('', 32914),
#  ('=', 2383),
#  ('in', 689),
#  ('#', 604),
#  ('if', 540),
#  ('for', 493),
#  ('==', 372),
#  ('i', 357),
#  ('수', 320),
#  (':', 281),
#  ('+', 281),
#  ('어떻게', 270),
#  ('오류가', 215),
#  ('1', 204),
#  ('a', 204),
#  ('이렇게', 193),
#  ('*', 191),
#  ('이', 176),
#  ('import', 171),
#  ('있는', 159),
#  ('제가', 154),
#  ('0', 154),
#  ('코드를', 154),
#  ('때', 152),
#  ('데이터', 150),
#  ('어떤', 148),
#  ('혹시', 146),
#  ('에러가', 137),
#  ('-', 137),
#  ('같이', 136),
#  ('잘', 135),
#  ('왜', 132),
#  ('not', 129),
#  ('같은', 125),
#  ('것', 124),
#  ('2', 122),
#  ('else:', 120),
#  ('return', 114),
#  ('있을까요?', 111),
#  ('값을', 111),
#  ('x', 108),
#  ('-&gt;', 108),
#  ('궁금합니다.', 107),
#  ('경우', 105),
#  ('elif', 102),
#  ('해당', 99),
#  ('and', 99),
#  ('다시', 98),
#  ('[]', 96),
#  ('코드', 95),
#  ('감사합니다.', 95),
#  ('값이', 94),
#  ('b', 93),
#  ('or', 90),
#  ('+=', 89),
#  ('안녕하세요', 88),
#  ('계속', 86),
#  ('한', 85),
#  ('하면', 83),
#  ('하는', 82),
#  ('질문', 78),
#  ('문제', 77),
#  ('def', 77),
#  ('문제가', 77),
#  (')', 76),
#  ('다른', 75),
#  ('%', 75),
#  ('이런', 74),
#  ('while', 74),
#  ('break', 73),
#  ('from', 73),
#  ('of', 73),
#  ('확인', 73),
#  ('를', 72),
#  ('부분이', 72),
#  ('모두', 72),
#  ('알', 71),
#  ('the', 71),
#  ('중', 71),
#  ('result', 71),
#  ('아니면', 70),
#  ('n', 69),
#  ('안', 68),
#  ('할', 67),
#  ('되는', 66),
#  ('결과가', 65),
#  ('다', 63),
#  ('문의', 62),
#  ('그', 62),
#  ('했는데', 62),
#  ('as', 61),
#  ('is', 61),
#  ('ㅠㅠ', 61),
#  ('드립니다.', 61),
#  ('것이', 60),
#  ('그리고', 60),
#  ('3', 60),
#  ('건가요?', 60),
#  ('상을', 59),
#  ('후', 59),
#  ('이유가', 59),
#  (',', 58),
#  ('2.', 58),
#  ('다음과', 58),
#  ('plt.show()', 58),
#  ('방법이', 57),
#  ('안녕하세요!', 57),
#  ('모델', 57),
#  ('sys', 57),
#  ('질문드립니다.', 56),
#  ('실습', 55),
#  ('있습니다.', 55),
#  ('int(input())', 55),
#  ('케이스', 54),
#  ('to', 54),
#  ('데이터를', 54),
#  ('안녕하세요.', 54),
#  ('같습니다.', 53),
#  ('y', 53),
#  ('나오는데', 53),
#  ('두', 53),
#  ('문의드립니다.', 53),
#  ('이해가', 52),
#  ('알고', 52),
#  ('문제를', 52),
#  ('로', 52),
#  ('여기서', 52),
#  ('-*-', 52),
#  ('모르겠습니다.', 51),
#  ('j', 51),
#  ('해야', 51),
#  ('1.', 51),
#  ('부분을', 50),
#  ('같은데', 49),
#  ('--&gt;', 49),
#  ('5', 49),
#  ('위와', 48),
#  ('하는데', 48),
#  ('하나요?', 48),
#  ('data', 47),
#  ('에서', 47),
#  ('라고', 47),
#  ('있나요?', 47),
#  ('10', 47),
#  ('이동', 46),
#  ('1,', 46),
#  ('뜹니다.', 46),
#  ('call', 46),
#  ('위해', 46),
#  ('&gt;=', 46),
#  ('4', 46),
#  ('&gt;', 45),
#  ('&', 45),
#  ('되지', 45),
#  ('s', 44),
#  ('될까요?', 44),
#  ('라는', 44),
#  ('싶습니다.', 43),
#  ('model', 43),
#  ('0:', 43),
#  ('코드에서', 42),
#  ('각', 42),
#  ('1)', 42),
#  ('때,', 42),
#  ('_', 42),
#  ('가장', 42),
#  ('위', 42),
#  ('c', 42),
#  ('결측치', 41),
#  ('(most', 41),
#  ('recent', 41),
#  ('해서', 41),
#  ('&lt;=', 41),
#  ('있는지', 41),
#  ('부분에서', 41),
#  ('입력', 41),
#  ('마지막', 41),
#  ('나오는', 41),
#  ('대한', 40),
#  ('변수', 40),
#  ('ValueError:', 40),
#  ('Traceback', 40),
#  ('with', 40),
#  ('else', 40),
#  ('대해', 40),
#  ('있는데', 40),
#  ('그런데', 39),
#  ('0,', 39),
#  ('차이가', 39),
#  ('예제', 39),
#  ('항상', 39),
#  ('더', 38),
#  ('나옵니다.', 38),
#  ('리스트', 38),
#  ('감사합니다!', 38),
#  ('전처리', 38),
#  ('따로', 38),
#  ('뜨는데', 38),
#  ('아래', 38),
#  ('않고', 37),
#  ('True:', 37),
#  ('파일', 37),
#  ('last)', 37),
#  ('와', 37),
#  ('과정에서', 37),
#  ('3,', 37),
#  ('을', 37),
#  ('N', 37),
#  ('건지', 37),
#  ('그대로', 36),
#  ('test', 36),
#  ('2,', 36),
#  ('코드는', 35),
#  ('count', 35),
#  ('train', 35),
#  ('으로', 35),
#  ('답변', 35),
#  ('보면', 35),
#  ('합니다.', 35),
#  ('d', 35),
#  ('하고', 35),
#  ('발생합니다.', 34),
#  ('be', 34),
#  ('문제에서', 34),
#  ('/', 34),
#  ('것으로', 34),
#  ('결과', 34),
#  ('않습니다.', 34),
#  ('출력', 34),
#  ('가', 34),
#  ('것인지', 33),
#  ('잘못', 33),
#  ('뭐가', 33),
#  ('떠서', 33),
#  ('모든', 33),
#  ('함수를', 33),
#  ('제', 33),
#  ('cnt', 33),
#  ('그냥', 32),
#  ('테스트', 32),
#  ('코드가', 32),
#  ('아래와', 32),
#  ('것을', 31),
#  ('기준으로', 31),
#  ('k', 31),
#  ('!=', 31),
#  ('100', 31),
#  ('궁금합니다', 31),
#  ('함수', 31),
#  ("'", 31),
#  ('되는지', 30),
#  ('object', 30),
#  ('됩니다.', 30),
#  ('하는지', 30),
#  ('통해', 30),
#  ('fail이', 29),
#  ('오류', 29),
#  ('잘못된', 29),
#  ('방법을', 29),
#  ('이미지', 29),
#  ('모르겠습니다', 29),
#  ('아니라', 29),
#  ('1:', 29),
#  ('현재', 29),
#  ('모델을', 29),
#  ('때는', 29),
#  ('아닌', 29),
#  ('continue', 29),
#  ('정상적으로', 28),
#  ('문제인지', 28),
#  ('관련', 28),
#  ('실행', 28),
#  ('주어진', 28),
#  ('출력이', 28),
#  ('제대로', 28),
#  ('않는', 28),
#  ('받는', 28),
#  ('또한', 27),
#  ('[1,', 27),
#  ('뒤에', 27),
#  ('inplace=True)', 27),
#  ('어느', 27),
#  ('의', 27),
#  ('&lt;', 27),
#  ('부탁드립니다.', 27),
#  ('num', 27),
#  ('M', 27),
#  ('input', 27),
#  ('때문에', 27),
#  ('각각', 27),
#  ('df.loc[df["자치구"]', 27),
#  ('"평균', 27),
#  ('시간(분)"]', 27),
#  ('결측치가', 26),
#  ('array', 26),
#  ('어디가', 26),
#  ('있어서', 26),
#  ('an', 26),
#  ('----&gt;', 26),
#  ('6', 26),
#  ('후에', 26),
#  ('큰', 26),
#  ('x,', 26),
#  ('A', 26),
#  ('input().split())', 26),
#  ('없는', 26),
#  ('4,', 26),
#  ('무엇인지', 26),
#  ('coding:', 26),
#  ('utf-8', 26),
#  ('시각화', 26),
#  ('학생이', 26),
#  ('---------------------------------------------------------------------------',
#   25),
#  ('X', 25),
#  ('다르게', 25),
#  ('학습', 25),
#  ('2)', 25),
#  ('shape', 25),
#  ('너무', 25),
#  ('answer', 25),
#  ('추가', 25),
#  ('시', 25),
#  ('있어', 25),
#  ('제거', 25),
#  ('7', 25),
#  ('만약', 25),
#  ('걸까요?', 25),
#  ('받을', 24),
#  ('on', 24),
#  ('이런식으로', 24),
#  ('뜹니다', 24),
#  ('않아', 24),
#  ('위에', 24),
#  ('강사님께서', 24),
#  ('map(int,', 24),
#  ('예를', 24),
#  ('자꾸', 24),
#  ('axis', 24),
#  ('감사합니다', 24),
#  ('파일을', 24),
#  ('No', 24),
#  ('file', 24),
#  ('바로', 24),
#  ('되는데', 24),
#  ('맞나요?', 24),
#  ('위의', 24),
#  ('되나요?', 24),
#  ('td', 24),
#  ('File', 24),
#  ('모델링', 23),
#  ('무슨', 23),
#  ('같아', 23),
#  ('설명', 23),
#  ('생성', 23),
#  ('수가', 23),
#  ('값', 23),
#  ('0이', 23),
#  ('이후', 22),
#  ('대해서', 22),
#  ('있을까요??', 22),
#  ('무엇이', 22),
#  ('열', 22),
#  ('다음', 22),
#  ('그래서', 22),
#  ('이유를', 22),
#  ('range(n):', 22),
#  ('안에', 22),
#  ('map(int,input().split())', 22),
#  ('5,', 22),
#  ('부분', 22),
#  ('궁금합니다!', 22),
#  ('오늘', 22),
#  ('int(sys.stdin.readline())', 22),
#  ('N,', 22),
#  ('True', 21),
#  ('했습니다.', 21),
#  ('문제에', 21),
#  ('사용하여', 21),
#  ('?', 21),
#  ('게', 21),
#  ('강사님', 21),
#  ('해도', 21),
#  ('했을', 21),
#  ('value', 21),
#  ('에러', 21),
#  ('지금', 21),
#  ('거', 21),
#  ('구하는', 21),
#  ('시군구', 20),
#  ('답이', 20),
#  ('무엇을', 20),
#  ('식으로', 20),
#  ('가능한', 20),
#  ('feature', 20),
#  ('values', 20),
#  ('ㅜㅜ', 20),
#  ('않은', 20),
#  ('나왔습니다.', 20),
#  ('a,', 20),
#  ('1로', 20),
#  ('input()', 20),
#  ('has', 20),
#  ('df_total', 20),
#  ('개수가', 20),
#  ('많은', 20),
#  ('m', 20),
#  ('이미지를', 20),
#  ('list(map(int,', 20),
#  ('총', 20),
#  ('변수를', 20),
#  ('안되는', 20),
#  ('변환', 20),
#  ('S', 20),
#  ('\\', 20),
#  ('따라', 19),
#  ('좋은', 19),
#  ('값으로', 19),
#  ('점이', 19),
#  ('열을', 19),
#  ('열이', 19),
#  ('여러', 19),
#  ('결과를', 19),
#  ('ㅠ', 19),
#  ('B', 19),
#  ('선언', 19),
#  ('줄에', 19),
#  ('이러한', 19),
#  ('이게', 19),
#  ('있다고', 19),
#  ('history', 19),
#  ('걸', 19),
#  ('납니다.', 19),
#  ('수도', 19),
#  ('없을', 19),
#  ('건', 19),
#  ('found', 18),
#  ('맞게', 18),
#  ('전체', 18),
#  ('그러면', 18),
#  ('key,', 18),
#  ('결과는', 18),
#  ('3.', 18),
#  ('보고', 18),
#  ('들어', 18),
#  ('3)', 18),
#  ('전부', 18),
#  ('채점', 18),
#  ('사용할', 18),
#  ('range(m):', 18),
#  ('≤', 18),
#  ('loop', 18),
#  ('tmp', 18),
#  ('무엇인가요?', 18),
#  ('내용을', 18),
#  ('numpy', 18),
#  ('label', 18),
#  ('!', 18),
#  ('이를', 18),
#  ('중에', 18),
#  ('궁금한', 18),
#  ('또', 18),
#  ('line', 18),
#  ('싶은데', 18),
#  ('분석', 17),
#  ('맞을까요?', 17),
#  ('리스트로', 17),
#  ('range(1,', 17),
#  ('지', 17),
#  ('및', 17),
#  ('것은', 17),
#  ('이미', 17),
#  ('activation', 17),
#  ('데이터가', 17),
#  ('columns', 17),
#  ('질문이', 17),
#  ('조건을', 17),
#  ('방법으로', 17),
#  (']', 17),
#  ('넣으면', 17),
#  ('8', 17),
#  ('cannot', 17),
#  ('처음', 17),
#  (':)', 17),
#  ('하지만', 17),
#  ('no', 17),
#  ('나와서', 17),
#  ('실행이', 17),
#  ('visited', 17),
#  ('값은', 17),
#  ('TypeError:', 17),
#  ('나서', 17),
#  ('1000', 17),
#  ('데이터프레임을', 17),
#  ('나오고', 17),
#  ('이유는', 17),
#  ('이전', 17),
#  ('그럼', 17),
#  ('이용해서', 17),
#  ('않아서', 17),
#  ('맞는', 17),
#  ('40', 17),
#  ('방법', 16),
#  ('결측치를', 16),
#  ('코드로', 16),
#  ('0으로', 16),
#  ('.', 16),
#  ('2번', 16),
#  ('코드에', 16),
#  ('첫', 16),
#  ('둘', 16),
#  ('KeyError', 16),
#  ('코딩마스터스', 16),
#  ('있을', 16),
#  ('못하고', 16),
#  ('만든', 16),
#  ('첨부한', 16),
#  ('남깁니다.', 16),
#  ('작성했는데', 16),
#  ('커트라인', 16),
#  ('입니다.', 16),
#  ('문제일까요?', 16),
#  ('할까요?', 16),
#  ('이상', 16),
#  ('저는', 16),
#  ('아래에', 16),
#  ('그래프가', 16),
#  ('하셨는데', 16),
#  ('인덱스', 16),
#  ('알려주시면', 16),
#  ('된', 16),
#  ('해결', 16),
#  ('뜨는', 16),
#  ('에', 16),
#  ('input().split()))', 16),
#  ("')", 16),
#  ('nan,', 16),
#  ('print(a8)', 16),
#  ('KeyError:', 15),
#  ('질문드립니다!', 15),
#  ('있으면', 15),
#  ('could', 15),
#  ('fit', 15),
#  ('list', 15),
#  ('모르겠어서', 15),
#  ('맞는지', 15),
#  ('정확히', 15),
#  ('이해를', 15),
#  ('한번에', 15),
#  ('되어', 15),
#  ('index', 15),
#  ('0)', 15),
#  ('부분에', 15),
#  ('데이터프레임', 15),
#  ('데이터프레임으로', 15),
#  ('method,', 15),
#  ('처럼', 15),
#  ('발생하는데', 15),
#  ('동일한', 15),
#  ('사용하면', 15),
#  ('첫번째', 15),
#  ('방금', 15),
#  ('1번', 15),
#  ('5번', 15),
#  ('나오지', 15),
#  ('관련하여', 15),
#  ('저', 15),
#  ('---&gt;', 15),
#  ('입력을', 15),
#  ('한번', 15),
#  ('경우가', 15),
#  ('출력하는', 15),
#  ('안되는데', 15),
#  ('는', 15),
#  ('작성한', 15),
#  ('실행하면', 15),
#  ('줄', 15),
#  ('안녕하세요,', 15),
#  ('sum', 15),
#  ('24', 15),
#  ('30', 15),
#  ('range(N):', 15),
#  ('target', 15),
#  ("activation='relu'))", 15),
#  ('사용하는', 14),
#  ('must', 14),
#  ('도움', 14),
#  ('이때', 14),
#  ('scaler', 14),
#  ('MinMaxScaler()', 14),
#  ('will', 14),
#  ('"""', 14),
#  ('raise', 14),
#  ('|', 14),
#  ('어제', 14),
#  ('볼', 14),
#  ('형태로', 14),
#  ('가지', 14),
#  ('결과값이', 14),
#  ('직접', 14),
#  ('e', 14),
#  ('쓰는', 14),
#  ('입력하면', 14),
#  ('"', 14),
#  ('또는', 14),
#  ('나는', 14),
#  ('**kwargs)', 14),
#  ('하여', 14),
#  ('attribute', 14),
#  ('답변을', 14),
#  ('못', 14),
#  ('20', 14),
#  ('강사님이', 14),
#  ('경우를', 14),
#  ('수업', 14),
#  ('번', 14),
#  ('주신', 14),
#  ('하나', 14),
#  ('수를', 14),
#  ('그렇다면', 14),
#  ('최대', 14),
#  ('과', 14),
#  ('192', 14),
#  ('1]', 14),
#  ('받은', 14),
#  ('pop', 14),
#  ('key', 14),
#  ('행', 14),
#  ('문자열에서', 14),
#  ('True)', 13),
#  ('s\t', 13),
#  ('convert', 13),
#  ('string', 13),
#  ('The', 13),
#  ('코딩', 13),
#  ('감사하겠습니다.', 13),
#  ('의미가', 13),
#  ('파일이', 13),
#  ('하나의', 13),
#  ('없이', 13),
#  ('튜터님!', 13),
#  ('데이터의', 13),
#  ('있을까요...?', 13),
#  ('경우에', 13),
#  ('대하여', 13),
#  ('60', 13),
#  ('추가적으로', 13),
#  ('사진처럼', 13),
#  ('그래프', 13),
#  ('개수를', 13),
#  ('이해한', 13),
#  ('사용', 13),
#  ('하나만', 13),
#  ('경우의', 13),
#  ('문자열', 13),
#  ('y_train,', 13),
#  ('가지고', 13),
#  ('앞에', 13),
#  ('각각의', 13),
#  ('진행이', 13),
#  ('방법은', 13),
#  ('such', 13),
#  ('특정', 13),
#  ('해야하나요?', 13),
#  ('val', 13),
#  ('튜터님,', 13),
#  ('실행시', 13),
#  ('생겨', 13),
#  ('Epoch', 13),
#  ('encoding', 13),
#  ('2]', 13),
#  ('사용해서', 13),
#  ('것인가요?', 13),
#  ('실습문제', 13),
#  ('많이', 13),
#  ('방식으로', 13),
#  ('밑에', 13),
#  ('형식으로', 13),
#  ('non-null', 13),
#  ('어디서', 12),
#  ('temp', 12),
#  ('나왔는데', 12),
#  ('그렇지', 12),
#  ('match', 12),
#  ('드립니다', 12),
#  ('있다면', 12),
#  ('안됩니다.', 12),
#  ('코딩을', 12),
#  ('개의', 12),
#  ('경우에는', 12),
#  ('진행', 12),
#  ('하지', 12),
#  ('1):', 12),
#  ('무조건', 12),
#  ('번째', 12),
#  ('문제의', 12),
#  ('경우,', 12),
#  ('r', 12),
#  ('처리', 12),
#  ('된다고', 12),
#  ('입력값', 12),
#  ('감사드립니다.', 12),
#  ('될까요??', 12),
#  ('배열', 12),
#  ('개수', 12),
#  ('6,', 12),
#  ('입력한', 12),
#  ('value)', 12),
#  ('level,', 12),
#  ('axis,', 12),
#  ('p', 12),
#  ('경우는', 12),
#  ('만들어서', 12),
#  ('16', 12),
#  ('출력값', 12),
#  ('한다고', 12),
#  ('//', 12),
#  ('directory:', 12),
#  ('않습니다', 12),
#  ('나옵니다', 12),
#  ('error:', 12),
#  ("',", 12),
#  ('Hey!', 12),
#  ('전처리를', 12),
#  ('n,', 12),
#  ('만', 12),
#  ('x_train,', 12),
#  ('숫자가', 12),
#  ('작은', 12),
#  ('pandas', 12),
#  ('사진', 12),
#  ('제일', 12),
#  ('새로운', 12),
#  ('얻을', 12),
#  ('아무리', 12),
#  ('d1=collections.Counter(a)', 12),
#  ('없는데', 12),
#  ('정점', 12),
#  ('labels', 12),
#  ('프레임', 12),
#  ('(a', 12),
#  ('win', 12),
#  ('((n[i][j]', 12),
#  ('(n[i', 12),
#  ('n1][j]', 12),
#  ('*\\n*', 12),
#  ('알려주실', 11),
#  ('주시면', 11),
#  ('평균', 11),
#  ('조건이', 11),
#  ('정수', 11),
#  ('작성하였는데', 11),
#  ('하였는데', 11),
#  ('df', 11),
#  ('뒤', 11),
#  ('써서', 11),
#  ('감사합니다!!', 11),
#  ('작성', 11),
#  ('하는데,', 11),
#  ('나온', 11),
#  ('정답이', 11),
#  ('end', 11),
#  ('validation', 11),
#  ('수정하면', 11),
#  ('만들어', 11),
#  ('넣어야', 11),
#  ('나머지', 11),
#  ('추출', 11),
#  ('{}', 11),
#  ('메시지가', 11),
#  ('맨', 11),
#  ('batch_size', 11),
#  ('아까', 11),
#  ('있었습니다.', 11),
#  ('되었습니다.', 11),
#  ('range(5):', 11),
#  ('plt.grid()', 11),
#  ('18', 11),
#  ('나는데', 11),
#  ('데이터로', 11),
#  ('성능', 11),
#  ('이하의', 11),
#  ('range(0,', 11),
#  ('이건', 11),
#  ('이거', 11),
#  ('하니', 11),
#  ('실습코드를', 11),
#  ('작성하고', 11),
#  ('var', 11),
#  ('여전히', 11),
#  ('쓸', 11),
#  ('np', 11),
#  ('넣고', 11),
#  ('got', 11),
#  ('그래프를', 11),
#  ('불러오기', 11),
#  ('뽑아서', 11),
#  ('features', 11),
#  ('[Errno', 11),
#  ('K명', 11),
#  ('최댓값을', 11),
#  ('b)', 11),
#  ('인덱스를', 11),
#  ('스케일링', 11),
#  ('만들고', 11),
#  ('해결해야', 11),
#  ('날짜', 11),
#  ('위해서', 11),
#  ('0):', 11),
#  ('말고', 10),
#  ('2의', 10),
#  ('결과값을', 10),
#  ('sklearn.preprocessing', 10),
#  ('MinMaxScaler', 10),
#  ('float:', 10),
#  ('그런', 10),
#  ('at', 10),
#  ('ValueError', 10),
#  ('only', 10),
#  ('Input', 10),
#  ('만드는', 10),
#  ('나오게', 10),
#  ('저장하는', 10),
#  ('새로', 10),
#  ('"/"', 10),
#  ('진행해야', 10),
#  ('하는게', 10),
#  ('파일로', 10),
#  ('예측', 10),
#  ('내용', 10),
#  ('length', 10),
#  ('except', 10),
#  ('궁금해서', 10),
#  ('요소', 10),
#  ('하셨는데,', 10),
#  ('했는데,', 10),
#  ('건가요??', 10),
#  ('이용해', 10),
#  ('작성하였습니다.', 10),
#  ('graph', 10),
#  ('False', 10),
#  ('할지', 10),
#  ('원인이', 10),
#  ('숫자', 10),
#  ('reindex', 10),
#  ('fill_value,', 10),
#  ('epochs', 10),
#  ('전', 10),
#  ("'))", 10),
#  ('전에', 10),
#  ('파라미터', 10),
#  ('test_x', 10),
#  ('7,', 10),
#  ('train_y)', 10),
#  ('print(a)', 10),
#  ('아직', 10),
#  ('19', 10),
#  ('v', 10),
#  ('길이가', 10),
#  ('감이', 10),
#  ('해야할지', 10),
#  ('z', 10),
#  ('수는', 10),
#  ('좀', 10),
#  ('반복', 10),
#  ('않나요?', 10),
#  ('keyword', 10),
#  ('범위를', 10),
#  ('파라미터를', 10),
#  ('타입', 10),
#  ('-1', 10),
#  ('함수의', 10),
#  ('failed가', 10),
#  ('지정', 10),
#  ('module', 10),
#  ('해당하는', 10),
#  ('오류는', 10),
#  ('아래는', 10),
#  ('0]', 10),
#  ('똑같이', 10),
#  ('경로를', 10),
#  ('layer', 10),
#  ('but', 10),
#  ('있는데,', 10),
#  ('a[i]', 10),
#  ('값과', 10),
#  ('실행을', 10),
#  ('입력이', 10),
#  ('원래', 10),
#  ('만들기', 10),
#  ('datetime', 10),
#  ('train_y,', 10),
#  ('have', 10),
#  ('x_val', 10),
#  ('**', 10),
#  ('하나씩', 10),
#  ('출력하세요.', 10),
#  ('csv', 10),
#  ('모델링을', 10),
#  ('뜨면서', 10),
#  ('response', 10),
#  ('bins', 10),
#  ('\t', 10),
#  ('것처럼', 10),
#  ('미리보기', 10),
#  ('70', 10),
#  ("'9',", 10),
#  ('가변수화', 10),
#  ('min', 10),
#  ('max', 10),
#  ('print(a4)', 10),
#  ('18/18', 10),
#  ('[==============================]', 10),
#  ('0s', 10),
#  ('1ms/step', 10),
#  ('loss:', 10),
#  ('0.3726', 10),
#  ('accuracy:', 10),
#  ('0.6274', 10),
#  ('사용해야', 9),
#  ('inplace', 9),
#  ('이라고', 9),
#  ('사진과', 9),
#  ('받아', 9),
#  ('x:', 9),
#  ('error', 9),
#  ('(', 9),
#  ('using', 9),
#  ('following', 9),
#  ('문의드립니다!', 9),
#  ('첨부', 9),
#  ('변수로', 9),
#  ('걸로', 9),
#  ('결국', 9),
#  ('못하는', 9),
#  ('학습을', 9),
#  ('출력값이', 9),
#  ('행을', 9),
#  ('없다고', 9),
#  ('indexer', 9),
#  ('None:', 9),
#  ('알수', 9),
#  ('아예', 9),
#  ('두번째', 9),
#  ('위치에', 9),
#  ('point', 9),
#  ('놓친', 9),
#  ('궁금하여', 9),
#  ('자동으로', 9),
#  ('다름이', 9),
#  ('~\\anaconda3\\lib\\site-packages\\pandas\\core\\generic.py', 9),
#  ('행이', 9),
#  ('복사', 9),
#  ('조금', 9),
#  ('이해하면', 9),
#  ('진행을', 9),
#  ('하려고', 9),
#  ('입력했는데', 9),
#  ('위치를', 9),
#  ('pass', 9),
#  ('q', 9),
#  ('a,b', 9),
#  ('프로그램을', 9),
#  ('test_y', 9),
#  ('해야하는지', 9),
#  ('model.fit(train_x,', 9),
#  ('관련해서', 9),
#  ('3:', 9),
#  ('배열로', 9),
#  ('코드와', 9),
#  ("입력하세요.:'))", 9),
#  ('")', 9),
#  ('n,m', 9),
#  ('했는데도', 9),
#  ('튜터님', 9),
#  ('숫자를', 9),
#  ('처음에', 9),
#  ('argument', 9),
#  ('cv', 9),
#  ('clear_session()', 9),
#  ('싶어서', 9),
#  ('아래처럼', 9),
#  ('결과,', 9),
#  ('2개', 9),
#  ('않는데', 9),
#  ('{', 9),
#  ('2:', 9),
#  ('axes[class_count,', 9),
#  ('처음부터', 9),
#  ('per', 9),
#  ('라이브러리', 9),
#  ('후,', 9),
#  ('ex)', 9),
#  ('n:', 9),
#  ('은', 9),
#  ('되고', 9),
#  ('[0,', 9),
#  ('cst', 9),
#  ('출력하면', 9),
#  ('이전에', 9),
#  ('질문을', 9),
#  ...]

# %% [markdown]
# ### <span style="color:green;background-color:#fff5b1">[미션4] 데이터 전처리하기

# %% [markdown]
# 전처리하지 않은 데이터로 워드클라우드를 만들면 특수문자, 조사, 인사말 등 불용어의 반복이 많아 인사이트 도출이 어렵습니다.
# 그래서 데이터 클렌징 작업을 통해 의미있는 키워드만 분류해서 다시 워드클라우드를 생성 합니다.
# * 특수문자 제거하기
# * 단어 분리하기
# * 불용어 제거하기
# * 한글자 단어 제거하기

# %%
# [실행코드] 특수문자 제거 함수 실행
## 아래의 함수 생성 코드를 실행해 주세요
## 아래의 특수문자 이외의 특수문제 제거가 필요한 경우 자유롭게 추가하여 사용하세요.

removal_list =  "‘, ’, ◇, ‘, ”,  ’, ', ·, \“, ·, △, ●,  , ■, (, ), \", >>, `, /, #, ∼, =,ㆍ<,>, .,?, !,【,】, …, ◆,%, ₩"
def remove_special(sentence: str = None):

    sentence = re.sub("[.,\'\"’‘”“!?]", "", sentence)
    sentence = re.sub("[^ㄱ-ㅎ가-힣a-zA-Z\\s]", " ", sentence)
    sentence = re.sub("\s+", " ", sentence)
    sentence = sentence.translate(str.maketrans(removal_list, ' '*len(removal_list)))
    sentence = sentence.strip()
    sentence = sentence.replace('\n', ' ')

    return sentence

# [실행코드] 특수문자를 제거하는 함수

# %%
# 특수문자 제거하기
## data['문의내용'] 각 행에서 특수 문제를 제거 후 결과를 담을 data['특수문자제거'] 빈 열을 생성 합니다.
## remove_special 함수를 사용하여 data['문의내용']의 각 행에서 특수문자를 제거하고 data['특수문자제거'] 열에 결과를 할당해 주세요.


data['특수문자제거'] = ''




data
# Out:
#                                                    문의내용    문의유형  \
# 0     inplace= True 를 사용하는 기준이 존재하는 것인지, 아니면 함수나 메소드...     코드2
# 1            참조파일2에 대한 (yolo부분) 답안 파일이 올라오지 않은 것 같습니다!   시스템 운영
# 2     AICE 시험 관련하여 이렇게 1대1로 질문하는게 맞나요..? 맞다면, 질문드립니다...  시스템 운영
# 3     예제는 잘 작동한 것 같은데 채점하니 케이스 1만 성공하고 나머지가 fail이 떠 ...     코드1
# 4     제주관광공사를 대상으로 관광지 순환 버스 솔루션을 도입하여 운전을 못하는 관광객 유...      이론
# ...                                                 ...     ...
# 3785  어디가 잘못되었는지 모르겠어요ㅜㅜ  N = list(map(int, input()....     코드1
# 3786  실습교안 102 쪽 진행중인데 이전단계에서 실습 교안대로 진행했는데 사진처럼 나옵니...       웹
# 3787                                 ubuntu 파일 이 안 열립니다       웹
# 3788  4. 데이터 분석 항복에 있는 6개의 문제에 대한 코드와 그래프 확인 부탁드립니다....     코드2
# 3789  img_list는 train의 jpg 리스트  for i in img_list:  ...     코드2
#
#                                                  특수문자제거
# 0     inplace True 를 사용하는 기준이 존재하는 것인지 아니면 함수나 메소드에 ...
# 1                참조파일 에 대한 yolo부분 답안 파일이 올라오지 않은 것 같습니다
# 2     AICE 시험 관련하여 이렇게 대 로 질문하는게 맞나요 맞다면 질문드립니다 구글링이...
# 3     예제는 잘 작동한 것 같은데 채점하니 케이스 만 성공하고 나머지가 fail이 떠 실...
# 4     제주관광공사를 대상으로 관광지 순환 버스 솔루션을 도입하여 운전을 못하는 관광객 유...
# ...                                                 ...
# 3785  어디가 잘못되었는지 모르겠어요 N list map int input split n ...
# 3786  실습교안 쪽 진행중인데 이전단계에서 실습 교안대로 진행했는데 사진처럼 나옵니다 실습...
# 3787                                 ubuntu 파일 이 안 열립니다
# 3788  데이터 분석 항복에 있는 개의 문제에 대한 코드와 그래프 확인 부탁드립니다 나름 결...
# 3789  img list는 train의 jpg 리스트 for i in img list img...
#
# [3790 rows x 3 columns]

# %%
# 단어 분리하기
## data['특수문자제거'] 각 행의 문장을 단어의 모음으로 분리 한 결과를 담을 data['단어분리'] 빈 열을 생성 합니다.
## 반복문을 사용하여 data['특수문자제거']의 각 행의 문장을 띄어쓰기(' ') 기준으로 split 하여
## 같은 행의 data['단어분리'] 열에 할당 합니다.
## [참고] 딥러닝 시간에 배운 KoNLPy 라이브러리의 Okt 형태소 분석기를 사용해도 됩니다.

data['단어분리'] = ''



data
# Out:
#                                                    문의내용    문의유형  \
# 0     inplace= True 를 사용하는 기준이 존재하는 것인지, 아니면 함수나 메소드...     코드2
# 1            참조파일2에 대한 (yolo부분) 답안 파일이 올라오지 않은 것 같습니다!   시스템 운영
# 2     AICE 시험 관련하여 이렇게 1대1로 질문하는게 맞나요..? 맞다면, 질문드립니다...  시스템 운영
# 3     예제는 잘 작동한 것 같은데 채점하니 케이스 1만 성공하고 나머지가 fail이 떠 ...     코드1
# 4     제주관광공사를 대상으로 관광지 순환 버스 솔루션을 도입하여 운전을 못하는 관광객 유...      이론
# ...                                                 ...     ...
# 3785  어디가 잘못되었는지 모르겠어요ㅜㅜ  N = list(map(int, input()....     코드1
# 3786  실습교안 102 쪽 진행중인데 이전단계에서 실습 교안대로 진행했는데 사진처럼 나옵니...       웹
# 3787                                 ubuntu 파일 이 안 열립니다       웹
# 3788  4. 데이터 분석 항복에 있는 6개의 문제에 대한 코드와 그래프 확인 부탁드립니다....     코드2
# 3789  img_list는 train의 jpg 리스트  for i in img_list:  ...     코드2
#
#                                                  특수문자제거  \
# 0     inplace True 를 사용하는 기준이 존재하는 것인지 아니면 함수나 메소드에 ...
# 1                참조파일 에 대한 yolo부분 답안 파일이 올라오지 않은 것 같습니다
# 2     AICE 시험 관련하여 이렇게 대 로 질문하는게 맞나요 맞다면 질문드립니다 구글링이...
# 3     예제는 잘 작동한 것 같은데 채점하니 케이스 만 성공하고 나머지가 fail이 떠 실...
# 4     제주관광공사를 대상으로 관광지 순환 버스 솔루션을 도입하여 운전을 못하는 관광객 유...
# ...                                                 ...
# 3785  어디가 잘못되었는지 모르겠어요 N list map int input split n ...
# 3786  실습교안 쪽 진행중인데 이전단계에서 실습 교안대로 진행했는데 사진처럼 나옵니다 실습...
# 3787                                 ubuntu 파일 이 안 열립니다
# 3788  데이터 분석 항복에 있는 개의 문제에 대한 코드와 그래프 확인 부탁드립니다 나름 결...
# 3789  img list는 train의 jpg 리스트 for i in img list img...
#
#                                                    단어분리
# 0     [inplace, True, 를, 사용하는, 기준이, 존재하는, 것인지, 아니면, ...
# 1     [참조파일, 에, 대한, yolo부분, 답안, 파일이, 올라오지, 않은, 것, 같습니다]
# 2     [AICE, 시험, 관련하여, 이렇게, 대, 로, 질문하는게, 맞나요, 맞다면, 질...
# 3     [예제는, 잘, 작동한, 것, 같은데, 채점하니, 케이스, 만, 성공하고, 나머지가...
# 4     [제주관광공사를, 대상으로, 관광지, 순환, 버스, 솔루션을, 도입하여, 운전을, ...
# ...                                                 ...
# 3785  [어디가, 잘못되었는지, 모르겠어요, N, list, map, int, input,...
# 3786  [실습교안, 쪽, 진행중인데, 이전단계에서, 실습, 교안대로, 진행했는데, 사진처럼...
# 3787                           [ubuntu, 파일, 이, 안, 열립니다]
# 3788  [데이터, 분석, 항복에, 있는, 개의, 문제에, 대한, 코드와, 그래프, 확인, ...
# 3789  [img, list는, train의, jpg, 리스트, for, i, in, img...
#
# [3790 rows x 4 columns]

# %%
# [실행코드] 조사, 인사말, 불용어 제거 함수 실행
## 아래의 함수 생성 코드를 실행해 주세요
## 아래의 불용어 이외의 불용어 제거가 필요한 경우 자유롭게 추가하여 사용하세요. 

def remove_stopword(sent):
    stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','을','으로','자','에','와','한','이', '로', '에서', '하는', '하면', '하고', '요', '혹시', '합니다', '감사합니다', '안녕하세요']
    removed = [word for word in sent if not word in stopwords] # 불용어 제거
    return removed

# [실행코드] 조사, 인사말, 불용어를 제거하는 함수

# %%
# 불용어 제거하기
## 자연어를 예측할 때 데이터에 조사, 접속사, 감탄사, 인사말 등이 포함되면 불필요한 자원 및 시간을 사용 할 수 있습니다.
## 불필요한 자원사용 방지를 위해 데이터에서 불용어를 제거해 줍니다.
## data['단어분리'] 에서 불용어를 제한 한 뒤 결과를 담을 data['불용어제거'] 열을 생성해 줍니다.
## remove_stopword 함수를 사용하여 data['단어분리']에서 불용어를 제거하고 결과를 data['불용어제거'] 열에 할당 합니다.
## [TIP] 모델의 정확도 향상을 위해 제거하고 싶은 불용어가 있을 경우 remove_stopword 함수의 stopwords 변수에 추가해 주세요.

data['불용어제거'] = ""





data
# Out:
#                                                    문의내용    문의유형  \
# 0     inplace= True 를 사용하는 기준이 존재하는 것인지, 아니면 함수나 메소드...     코드2
# 1            참조파일2에 대한 (yolo부분) 답안 파일이 올라오지 않은 것 같습니다!   시스템 운영
# 2     AICE 시험 관련하여 이렇게 1대1로 질문하는게 맞나요..? 맞다면, 질문드립니다...  시스템 운영
# 3     예제는 잘 작동한 것 같은데 채점하니 케이스 1만 성공하고 나머지가 fail이 떠 ...     코드1
# 4     제주관광공사를 대상으로 관광지 순환 버스 솔루션을 도입하여 운전을 못하는 관광객 유...      이론
# ...                                                 ...     ...
# 3785  어디가 잘못되었는지 모르겠어요ㅜㅜ  N = list(map(int, input()....     코드1
# 3786  실습교안 102 쪽 진행중인데 이전단계에서 실습 교안대로 진행했는데 사진처럼 나옵니...       웹
# 3787                                 ubuntu 파일 이 안 열립니다       웹
# 3788  4. 데이터 분석 항복에 있는 6개의 문제에 대한 코드와 그래프 확인 부탁드립니다....     코드2
# 3789  img_list는 train의 jpg 리스트  for i in img_list:  ...     코드2
#
#                                                  특수문자제거  \
# 0     inplace True 를 사용하는 기준이 존재하는 것인지 아니면 함수나 메소드에 ...
# 1                참조파일 에 대한 yolo부분 답안 파일이 올라오지 않은 것 같습니다
# 2     AICE 시험 관련하여 이렇게 대 로 질문하는게 맞나요 맞다면 질문드립니다 구글링이...
# 3     예제는 잘 작동한 것 같은데 채점하니 케이스 만 성공하고 나머지가 fail이 떠 실...
# 4     제주관광공사를 대상으로 관광지 순환 버스 솔루션을 도입하여 운전을 못하는 관광객 유...
# ...                                                 ...
# 3785  어디가 잘못되었는지 모르겠어요 N list map int input split n ...
# 3786  실습교안 쪽 진행중인데 이전단계에서 실습 교안대로 진행했는데 사진처럼 나옵니다 실습...
# 3787                                 ubuntu 파일 이 안 열립니다
# 3788  데이터 분석 항복에 있는 개의 문제에 대한 코드와 그래프 확인 부탁드립니다 나름 결...
# 3789  img list는 train의 jpg 리스트 for i in img list img...
#
#                                                    단어분리  \
# 0     [inplace, True, 를, 사용하는, 기준이, 존재하는, 것인지, 아니면, ...
# 1     [참조파일, 에, 대한, yolo부분, 답안, 파일이, 올라오지, 않은, 것, 같습니다]
# 2     [AICE, 시험, 관련하여, 이렇게, 대, 로, 질문하는게, 맞나요, 맞다면, 질...
# 3     [예제는, 잘, 작동한, 것, 같은데, 채점하니, 케이스, 만, 성공하고, 나머지가...
# 4     [제주관광공사를, 대상으로, 관광지, 순환, 버스, 솔루션을, 도입하여, 운전을, ...
# ...                                                 ...
# 3785  [어디가, 잘못되었는지, 모르겠어요, N, list, map, int, input,...
# 3786  [실습교안, 쪽, 진행중인데, 이전단계에서, 실습, 교안대로, 진행했는데, 사진처럼...
# 3787                           [ubuntu, 파일, 이, 안, 열립니다]
# 3788  [데이터, 분석, 항복에, 있는, 개의, 문제에, 대한, 코드와, 그래프, 확인, ...
# 3789  [img, list는, train의, jpg, 리스트, for, i, in, img...
#
#                                                   불용어제거
# 0     [inplace, True, 사용하는, 기준이, 존재하는, 것인지, 아니면, 함수나...
# 1        [참조파일, 대한, yolo부분, 답안, 파일이, 올라오지, 않은, 것, 같습니다]
# 2     [AICE, 시험, 관련하여, 이렇게, 대, 질문하는게, 맞나요, 맞다면, 질문드립...
# 3     [예제는, 작동한, 것, 같은데, 채점하니, 케이스, 만, 성공하고, 나머지가, f...
# 4     [제주관광공사를, 대상으로, 관광지, 순환, 버스, 솔루션을, 도입하여, 운전을, ...
# ...                                                 ...
# 3785  [어디가, 잘못되었는지, 모르겠어요, N, list, map, int, input,...
# 3786  [실습교안, 쪽, 진행중인데, 이전단계에서, 실습, 교안대로, 진행했는데, 사진처럼...
# 3787                              [ubuntu, 파일, 안, 열립니다]
# 3788  [데이터, 분석, 항복에, 있는, 개의, 문제에, 대한, 코드와, 그래프, 확인, ...
# 3789  [img, list는, train의, jpg, 리스트, for, i, in, img...
#
# [3790 rows x 5 columns]

# %%
# 한글자 단어 제거하기
## 한글자 단어는 단어의 중요도에 비해 빈도수가 너무 높아 모델 정확도 향상에 방해가 될 수 있습니다.
## data['불용어제거'] 에 각 행에서 한글자 단어를 제거 후 결과를 담을 data['한글자제거'] 빈 열을 추가 합니다.
## 각 행마다 한글자 단어를 제거후 남은 단어들을 담을 data['한글자제거'] 열을 생성 합니다.
## 반복문을 사용하여 data['불용어제거'] 의 각 행에서 단어 추출하고 단어의 글자수(len)을 측정하여 2글자 이상인 단어만 data['한글자제거'] 열에 할당해 줍니다.
## [Tip] 2중 for 를 사용하여 data['불용어제거']에서 각 행을 불러오고, 불러온 각 행에서 단어들을 불러와서 한글자 단어를 제거 합니다.
## [Tip] 리스트 변수를 하나 생성하여 한글자 단어를 제거한 단어들을 나머지 단어들을 append 하고 해당 행의 두글자 이상의 단어들이 다 모이면 data['한글자제거']에 할당 합니다.

data['한글자제거'] = ""




data
# Out:
#                                                    문의내용    문의유형  \
# 0     inplace= True 를 사용하는 기준이 존재하는 것인지, 아니면 함수나 메소드...     코드2
# 1            참조파일2에 대한 (yolo부분) 답안 파일이 올라오지 않은 것 같습니다!   시스템 운영
# 2     AICE 시험 관련하여 이렇게 1대1로 질문하는게 맞나요..? 맞다면, 질문드립니다...  시스템 운영
# 3     예제는 잘 작동한 것 같은데 채점하니 케이스 1만 성공하고 나머지가 fail이 떠 ...     코드1
# 4     제주관광공사를 대상으로 관광지 순환 버스 솔루션을 도입하여 운전을 못하는 관광객 유...      이론
# ...                                                 ...     ...
# 3785  어디가 잘못되었는지 모르겠어요ㅜㅜ  N = list(map(int, input()....     코드1
# 3786  실습교안 102 쪽 진행중인데 이전단계에서 실습 교안대로 진행했는데 사진처럼 나옵니...       웹
# 3787                                 ubuntu 파일 이 안 열립니다       웹
# 3788  4. 데이터 분석 항복에 있는 6개의 문제에 대한 코드와 그래프 확인 부탁드립니다....     코드2
# 3789  img_list는 train의 jpg 리스트  for i in img_list:  ...     코드2
#
#                                                  특수문자제거  \
# 0     inplace True 를 사용하는 기준이 존재하는 것인지 아니면 함수나 메소드에 ...
# 1                참조파일 에 대한 yolo부분 답안 파일이 올라오지 않은 것 같습니다
# 2     AICE 시험 관련하여 이렇게 대 로 질문하는게 맞나요 맞다면 질문드립니다 구글링이...
# 3     예제는 잘 작동한 것 같은데 채점하니 케이스 만 성공하고 나머지가 fail이 떠 실...
# 4     제주관광공사를 대상으로 관광지 순환 버스 솔루션을 도입하여 운전을 못하는 관광객 유...
# ...                                                 ...
# 3785  어디가 잘못되었는지 모르겠어요 N list map int input split n ...
# 3786  실습교안 쪽 진행중인데 이전단계에서 실습 교안대로 진행했는데 사진처럼 나옵니다 실습...
# 3787                                 ubuntu 파일 이 안 열립니다
# 3788  데이터 분석 항복에 있는 개의 문제에 대한 코드와 그래프 확인 부탁드립니다 나름 결...
# 3789  img list는 train의 jpg 리스트 for i in img list img...
#
#                                                    단어분리  \
# 0     [inplace, True, 를, 사용하는, 기준이, 존재하는, 것인지, 아니면, ...
# 1     [참조파일, 에, 대한, yolo부분, 답안, 파일이, 올라오지, 않은, 것, 같습니다]
# 2     [AICE, 시험, 관련하여, 이렇게, 대, 로, 질문하는게, 맞나요, 맞다면, 질...
# 3     [예제는, 잘, 작동한, 것, 같은데, 채점하니, 케이스, 만, 성공하고, 나머지가...
# 4     [제주관광공사를, 대상으로, 관광지, 순환, 버스, 솔루션을, 도입하여, 운전을, ...
# ...                                                 ...
# 3785  [어디가, 잘못되었는지, 모르겠어요, N, list, map, int, input,...
# 3786  [실습교안, 쪽, 진행중인데, 이전단계에서, 실습, 교안대로, 진행했는데, 사진처럼...
# 3787                           [ubuntu, 파일, 이, 안, 열립니다]
# 3788  [데이터, 분석, 항복에, 있는, 개의, 문제에, 대한, 코드와, 그래프, 확인, ...
# 3789  [img, list는, train의, jpg, 리스트, for, i, in, img...
#
#                                                   불용어제거  \
# 0     [inplace, True, 사용하는, 기준이, 존재하는, 것인지, 아니면, 함수나...
# 1        [참조파일, 대한, yolo부분, 답안, 파일이, 올라오지, 않은, 것, 같습니다]
# 2     [AICE, 시험, 관련하여, 이렇게, 대, 질문하는게, 맞나요, 맞다면, 질문드립...
# 3     [예제는, 작동한, 것, 같은데, 채점하니, 케이스, 만, 성공하고, 나머지가, f...
# 4     [제주관광공사를, 대상으로, 관광지, 순환, 버스, 솔루션을, 도입하여, 운전을, ...
# ...                                                 ...
# 3785  [어디가, 잘못되었는지, 모르겠어요, N, list, map, int, input,...
# 3786  [실습교안, 쪽, 진행중인데, 이전단계에서, 실습, 교안대로, 진행했는데, 사진처럼...
# 3787                              [ubuntu, 파일, 안, 열립니다]
# 3788  [데이터, 분석, 항복에, 있는, 개의, 문제에, 대한, 코드와, 그래프, 확인, ...
# 3789  [img, list는, train의, jpg, 리스트, for, i, in, img...
#
#                                                   한글자제거
# 0     [inplace, True, 사용하는, 기준이, 존재하는, 것인지, 아니면, 함수나...
# 1           [참조파일, 대한, yolo부분, 답안, 파일이, 올라오지, 않은, 같습니다]
# 2     [AICE, 시험, 관련하여, 이렇게, 질문하는게, 맞나요, 맞다면, 질문드립니다,...
# 3     [예제는, 작동한, 같은데, 채점하니, 케이스, 성공하고, 나머지가, fail이, ...
# 4     [제주관광공사를, 대상으로, 관광지, 순환, 버스, 솔루션을, 도입하여, 운전을, ...
# ...                                                 ...
# 3785  [어디가, 잘못되었는지, 모르겠어요, list, map, int, input, sp...
# 3786  [실습교안, 진행중인데, 이전단계에서, 실습, 교안대로, 진행했는데, 사진처럼, 나...
# 3787                                 [ubuntu, 파일, 열립니다]
# 3788  [데이터, 분석, 항복에, 있는, 개의, 문제에, 대한, 코드와, 그래프, 확인, ...
# 3789  [img, list는, train의, jpg, 리스트, for, in, img, l...
#
# [3790 rows x 6 columns]

# %% [markdown]
# ### <span style="color:green;background-color:#fff5b1"> [미션5]워드클라우드 생성하기2</span>

# %% [markdown]
# 데이터 클렌징 전 생성한 WordCloud 와 데이터 클렌징 후 생성한 WordCloud 를 비교하고 차이점이 무엇인지 생각해 보세요.
# * data['문의유형'] 이 코드1, 코드2 데이터 분리하기
# * 단어 리스트 생성하기
# * 전체 단어 빈도수 카운트하기
# * 워드클라우드 만들기
# * 워드클라우드 비교하기

# %%
# data['문의유형'] 이 코드1, 코드2 데이터 분리하기
## data['문의유형'] 열의 값이(유형이) 코드1, 코드2 인 행의 data['문의내용'] 을 담을
## type_questions 변수를 pd.Series 타입으로 생성하고 초기화 합니다.
## 반복문을 사용하여 data['문의유형'] 열의 값이(유형이) '코드1', '코드2' 인 값을 type_questions 변수에 할당 합니다.


type_questions = pd.Series()





type_questions
# Out:
# C:\Users\qicha\AppData\Local\Temp\ipykernel_5632\2361326630.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   type_questions = pd.Series()
# 0       [inplace, True, 사용하는, 기준이, 존재하는, 것인지, 아니면, 함수나...
# 3       [예제는, 작동한, 같은데, 채점하니, 케이스, 성공하고, 나머지가, fail이, ...
# 9       [실습, 내용중, 오존, 변수의, 결측치를, 다른, 값으로, 바꿔서, 처리할려고, ...
# 15      [오존, 이변량, 분석, 중입니다, spstpearsonr, bike, ozone,...
# 20      [seoul, drop, seoul, movingloc, seoul, moving,...
#                               ...
# 3782    [문제에서, 외국인, 정보가, 년이, 누락되어, 결측치가, 발생할, 것입니다, 라고...
# 3783    [bins, trindata, PM, level, pdcut, traindata, ...
# 3785    [어디가, 잘못되었는지, 모르겠어요, list, map, int, input, sp...
# 3788    [데이터, 분석, 항복에, 있는, 개의, 문제에, 대한, 코드와, 그래프, 확인, ...
# 3789    [img, list는, train의, jpg, 리스트, for, in, img, l...
# Length: 1611, dtype: object

# %%
# 단어 리스트 생성하기
## 각 문의에서 단어를 분리해서 담을 cleansing_word_list 변수를 리스트 타입으로 생성 합니다.
## 이중 반복문을 사용하여 type_questions 데이터의 각 행에서 단어만 분리하여 cleansing_word_list 변수에 단어를 한개씩 append 해 줍니다.
## 최종 cleansing_word_list 의 차원이 1차원 인지 확인 합니다.


cleansing_word_list = []






cleansing_word_list
# Out:
# ['inplace',
#  'True',
#  '사용하는',
#  '기준이',
#  '존재하는',
#  '것인지',
#  '아니면',
#  '함수나',
#  '메소드에',
#  '따라',
#  '외워야하는',
#  '것인지',
#  '궁금합니다',
#  '또한',
#  'inplace를',
#  '사용해야',
#  '대표적인',
#  '함수나',
#  '메소드들이',
#  '궁금합니다',
#  '예제는',
#  '작동한',
#  '같은데',
#  '채점하니',
#  '케이스',
#  '성공하고',
#  '나머지가',
#  'fail이',
#  '실패했습니다',
#  '제가',
#  '어디서',
#  '틀렸는지',
#  '모르겠습니다',
#  '아니면',
#  '제가',
#  '방법',
#  '말고',
#  '좋은',
#  '방법이',
#  '있을까요',
#  '실습',
#  '내용중',
#  '오존',
#  '변수의',
#  '결측치를',
#  '다른',
#  '값으로',
#  '바꿔서',
#  '처리할려고',
#  '했습니다',
#  'target',
#  'ozone',
#  'temp',
#  'tr',
#  'abc',
#  'target',
#  'temp',
#  'tempfillna',
#  'tempunique',
#  '위와',
#  '같은',
#  '코드로',
#  '결측치를',
#  '바꿨고',
#  '유니크',
#  '메소드에서',
#  '정상적으로',
#  '표시되면서',
#  '바뀌는',
#  '것을',
#  '확인했습니다',
#  '그러나',
#  '이후',
#  '다시',
#  '유니크',
#  '메소드를',
#  '실행했더니',
#  '결측치가',
#  '바뀌지',
#  '않고',
#  'nan',
#  '값으로',
#  '표기되어서',
#  '나와',
#  '있습니다',
#  '어디서',
#  '잘못된건지',
#  '알려주실',
#  '있을까요',
#  '오존',
#  '이변량',
#  '분석',
#  '중입니다',
#  'spstpearsonr',
#  'bike',
#  'ozone',
#  'bike',
#  'count',
#  '이렇게',
#  '코드',
#  '쳤는데',
#  'array',
#  'must',
#  'not',
#  'contain',
#  'infs',
#  'or',
#  'NaNs',
#  '오류',
#  '문구가',
#  '뜨네요',
#  'seoul',
#  'drop',
#  'seoul',
#  'movingloc',
#  'seoul',
#  'moving',
#  '도착시간',
#  'seoul',
#  'drop',
#  'seoul',
#  'movingdrop',
#  'seoul',
#  'drop',
#  'inplace',
#  'True',
#  '위와',
#  '같은',
#  '코드에서',
#  '에러가',
#  '나옵니다',
#  'KeyError',
#  '대상연월',
#  '요일',
#  '도착시간',
#  '출발',
#  '시군구',
#  '코드',
#  '도착',
#  '시군구',
#  '코드',
#  '성별',
#  '나이',
#  '이동유형',
#  '평균',
#  '이동',
#  '시간',
#  '이동인구',
#  'not',
#  'found',
#  'in',
#  'axis',
#  '이런',
#  '에러가',
#  '나왔는데',
#  '어떤',
#  '점이',
#  '문제인지',
#  '이해가',
#  '안가서',
#  '설명해',
#  '주시면',
#  '감사하겠습니다',
#  'pltbarh',
#  'df',
#  'featurerffeature',
#  'importances',
#  '입력해도',
#  '중요도가',
#  '안나오는데',
#  '어디를',
#  '고치면',
#  '되는지',
#  '있을까요',
#  'ERROR',
#  'Unexpected',
#  'Column',
#  'Result',
#  'Line',
#  'Column',
#  '해당',
#  '에러의',
#  '원인을',
#  '알려주세요',
#  'while',
#  'True',
#  'red',
#  'int',
#  'input',
#  '빨간색',
#  '접시',
#  'gt',
#  'gt',
#  'blue',
#  'int',
#  'input',
#  '파란색',
#  '접시',
#  'gt',
#  'gt',
#  'green',
#  'int',
#  'input',
#  '초록색',
#  '접시',
#  'gt',
#  'gt',
#  'yellow',
#  'int',
#  'input',
#  '노란색',
#  '접시',
#  'gt',
#  'gt',
#  'black',
#  'int',
#  'input',
#  '검은색',
#  '접시',
#  'gt',
#  'gt',
#  'if',
#  'red',
#  'break',
#  'print',
#  '치훈이가',
#  '내야',
#  '초밥값',
#  'format',
#  'red',
#  'blue',
#  'green',
#  'yellow',
#  'black',
#  'print',
#  '프로그램이',
#  '종료되었습니다',
#  '코드는',
#  '이렇게',
#  '입력했습니다',
#  '예제출력',
#  '대한',
#  '답이',
#  '맞게',
#  '나왔다고',
#  '생각하는데',
#  'fail이라고',
#  '떠서요',
#  '어디가',
#  '문제일지',
#  '도움',
#  '받을',
#  '있을까요',
#  '케이스',
#  'fail',
#  '이라고',
#  '뜹니다',
#  '교안에',
#  '나와있는대로',
#  '평균',
#  '시속',
#  '변수',
#  'PerHour를',
#  '사진과',
#  '같이',
#  '생성했습니다',
#  '그런데',
#  '문제',
#  '조건이',
#  'PerHour',
#  '기준으로',
#  'km',
#  '초과의',
#  '수치는',
#  '제거하라는',
#  '건데',
#  '제가',
#  '구한',
#  'PerHour값의',
#  'MAX는',
#  '정도라',
#  '잘못된',
#  '같습니다',
#  '무엇을',
#  '잘못',
#  '계산한건지',
#  '궁금합니다',
#  'temp',
#  'titanicloc',
#  'titanic',
#  'Age',
#  'notnull',
#  'temploc',
#  'temp',
#  'Embarked',
#  'Age',
#  'temploc',
#  'temp',
#  'Embarked',
#  'Age',
#  'temploc',
#  'temp',
#  'Embarked',
#  'Age',
#  'spstf',
#  'oneway',
#  '이런',
#  '식으로',
#  '결측치가',
#  '있는',
#  '경우',
#  '결측치를',
#  '제거하고',
#  '아노바를',
#  '돌린다고',
#  '배웠는데',
#  '이때',
#  '결측치',
#  '제거는',
#  'target',
#  '되는',
#  '위의',
#  '경우',
#  'age',
#  '대상으로',
#  '지우는게',
#  '맞을까요',
#  '튜터님솔루션',
#  '파일',
#  '모델링',
#  '했을때',
#  '에러가',
#  '발생합니다',
#  '어떻게',
#  '해결할까요',
#  '가우스와',
#  '정다각형',
#  '문제',
#  '질문드립니다',
#  '정수',
#  'k를',
#  '받고',
#  '페르마',
#  '소수와',
#  '제곱수를',
#  '리스트로',
#  '받아',
#  '리스트',
#  'x에',
#  '가능한',
#  '정다각형을',
#  '넣었습니다',
#  '이후',
#  '입력받은',
#  'k가',
#  '리스트',
#  'x에',
#  '있으면',
#  '결과값을',
#  'YES',
#  '그렇지',
#  '않으면',
#  'NO로',
#  '출력하게',
#  '했습니다',
#  '그런데',
#  '케이스',
#  '개가',
#  '실패가',
#  '뜹니다',
#  '뭐가',
#  '원인인가요',
#  'gt',
#  'gt',
#  '코드',
#  'int',
#  'input',
#  'frm',
#  'frm',
#  'two',
#  'for',
#  'in',
#  'range',
#  'two',
#  'for',
#  'in',
#  'two',
#  'for',
#  'in',
#  'frm',
#  'for',
#  'in',
#  'frm',
#  'if',
#  'list',
#  'set',
#  'if',
#  'in',
#  'print',
#  'YES',
#  'else',
#  'print',
#  'NO',
#  'gt',
#  '채점결과',
#  '케이스',
#  'Passed',
#  '케이스',
#  'Passed',
#  '케이스',
#  'Failed',
#  '케이스',
#  'Passed',
#  '케이스',
#  'Passed',
#  '케이스',
#  'Passed',
#  '케이스',
#  'Failed',
#  '날짜를',
#  '주말',
#  '평일로',
#  '나누고',
#  '싶습니다',
#  '기존의',
#  'week',
#  's열에서',
#  'Sat과',
#  'Sun가',
#  '포함된',
#  '행에는',
#  '기존의',
#  'week',
#  's열에',
#  '나머지는',
#  '표시되는',
#  '열을',
#  '추가하고싶은데',
#  '어떻게',
#  '해야할까요',
#  'bike',
#  '주말',
#  'bike',
#  'sloc',
#  'bike',
#  'week',
#  'Sat',
#  'bike',
#  '주말',
#  'bike',
#  'bike',
#  'week',
#  'Sun',
#  'bike',
#  'from',
#  'sklearnpreprocessing',
#  'import',
#  'MinMaxScaler',
#  'scaler',
#  'MinMaxScaler',
#  'scalerfit',
#  'df',
#  'total',
#  '이렇게',
#  '작성하였는데',
#  'ValueError',
#  'could',
#  'not',
#  'convert',
#  'string',
#  'to',
#  'float',
#  'router',
#  'df',
#  'fc',
#  'nxc',
#  '이런',
#  '에러가',
#  '뜨는데요',
#  'string이',
#  '있어서',
#  '그런',
#  '같은데',
#  '뭔가',
#  '변환을',
#  '해줘야',
#  '하는건가요',
#  'Users',
#  'User',
#  'AppData',
#  'Roaming',
#  'Python',
#  'Python',
#  'site',
#  'packages',
#  'sklearn',
#  'basepy',
#  'FutureWarning',
#  'The',
#  'feature',
#  'names',
#  'should',
#  'match',
#  'those',
#  'that',
#  'were',
#  'passed',
#  'during',
#  'fit',
#  'Starting',
#  'version',
#  'an',
#  'error',
#  'will',
#  'be',
#  'raised',
#  'Feature',
#  'names',
#  'unseen',
#  'at',
#  'fit',
#  'time',
#  'Unnamed',
#  'html',
#  'num',
#  'tags',
#  'applet',
#  'url',
#  'chinese',
#  'present',
#  'url',
#  'domain',
#  'len',
#  'url',
#  'path',
#  'len',
#  'warningswarn',
#  'message',
#  'FutureWarning',
#  'ValueError',
#  'Traceback',
#  'most',
#  'recent',
#  'call',
#  'last',
#  'in',
#  'test',
#  'pdread',
#  'csv',
#  'test',
#  'dataset',
#  'csv',
#  'gt',
#  'pred',
#  'model',
#  'dtpredict',
#  'test',
#  'AppData',
#  'Roaming',
#  'Python',
#  'Python',
#  'site',
#  'packages',
#  'sklearn',
#  'tree',
#  'classespy',
#  'in',
#  'predict',
#  'self',
#  'check',
#  'input',
#  'check',
#  'is',
#  'fitted',
#  'self',
#  'gt',
#  'self',
#  'validate',
#  'predict',
#  'check',
#  'input',
#  'proba',
#  'selftree',
#  'predict',
#  'samples',
#  'Xshape',
#  'AppData',
#  'Roaming',
#  'Python',
#  'Python',
#  'site',
#  'packages',
#  'sklearn',
#  'tree',
#  'classespy',
#  'in',
#  'validate',
#  'predict',
#  'self',
#  'check',
#  'input',
#  'Validate',
#  'the',
#  'training',
#  'data',
#  'on',
#  'predict',
#  'probabilities',
#  'if',
#  'check',
#  'input',
#  'gt',
#  'self',
#  'validate',
#  'data',
#  'dtype',
#  'DTYPE',
#  'accept',
#  'sparse',
#  'csr',
#  'reset',
#  'False',
#  'if',
#  'issparse',
#  'and',
#  'Xindicesdtype',
#  'npintc',
#  'or',
#  'Xindptrdtype',
#  'npintc',
#  'AppData',
#  'Roaming',
#  'Python',
#  'Python',
#  'site',
#  'packages',
#  'sklearn',
#  'basepy',
#  'in',
#  'validate',
#  'data',
#  'self',
#  'reset',
#  'validate',
#  'separately',
#  'check',
#  'params',
#  'raise',
#  'ValueError',
#  'Validation',
#  'should',
#  'be',
#  'done',
#  'on',
#  'or',
#  'both',
#  'elif',
#  'not',
#  'no',
#  'val',
#  'and',
#  'no',
#  'val',
#  'gt',
#  'check',
#  'array',
#  'input',
#  'name',
#  'check',
#  'params',
#  'out',
#  'elif',
#  'no',
#  'val',
#  'and',
#  'not',
#  'no',
#  'val',
#  'AppData',
#  'Roaming',
#  'Python',
#  'Python',
#  'site',
#  'packages',
#  'sklearn',
#  'utils',
#  'validationpy',
#  'in',
#  'check',
#  'array',
#  'array',
#  'accept',
#  'sparse',
#  'accept',
#  'large',
#  'sparse',
#  'dtype',
#  'order',
#  'copy',
#  'force',
#  'all',
#  'finite',
#  'ensure',
#  'allow',
#  'nd',
#  'ensure',
#  'min',
#  'samples',
#  'ensure',
#  'min',
#  'features',
#  'estimator',
#  'input',
#  'name',
#  'if',
#  'force',
#  'all',
#  'finite',
#  'gt',
#  'assert',
#  'all',
#  'finite',
#  'array',
#  'input',
#  'name',
#  'input',
#  'name',
#  'AppData',
#  'Roaming',
#  'Python',
#  'Python',
#  'site',
#  'packages',
#  'sklearn',
#  'utils',
#  'validationpy',
#  'in',
#  'assert',
#  'all',
#  'finite',
#  'allow',
#  'nan',
#  'msg',
#  'dtype',
#  'estimator',
#  'name',
#  'input',
#  'name',
#  'estimators',
#  'that',
#  'handle',
#  'nan',
#  'values',
#  'gt',
#  'raise',
#  'ValueError',
#  'msg',
#  'err',
#  'for',
#  'object',
#  'dtype',
#  'data',
#  'we',
#  'only',
#  'check',
#  'for',
#  'NaNs',
#  'GH',
#  'ValueError',
#  'Input',
#  'contains',
#  'NaN',
#  'DecisionTreeClassifier',
#  'does',
#  'not',
#  'accept',
#  'missing',
#  'values',
#  'encoded',
#  'as',
#  'NaN',
#  'natively',
#  'For',
#  'supervised',
#  'learning',
#  'you',
#  'might',
#  'want',
#  'to',
#  'consider',
#  'sklearnensembleHistGradientBoostingClassifier',
#  'and',
#  'Regressor',
#  'which',
#  'accept',
#  'missing',
#  'values',
#  'encoded',
#  'as',
#  'NaNs',
#  'natively',
#  'Alternatively',
#  'it',
#  'is',
#  'possible',
#  'to',
#  'preprocess',
#  'the',
#  'data',
#  'for',
#  'instance',
#  'by',
#  'using',
#  'an',
#  'imputer',
#  'transformer',
#  'in',
#  'pipeline',
#  'or',
#  'drop',
#  'samples',
#  'with',
#  'missing',
#  'values',
#  'See',
#  'https',
#  'scikit',
#  'learnorg',
#  'stable',
#  'modules',
#  'imputehtml',
#  'You',
#  'can',
#  'find',
#  'list',
#  'of',
#  'all',
#  'estimators',
#  'that',
#  'handle',
#  'NaN',
#  'values',
#  'at',
#  'the',
#  'following',
#  'page',
#  'https',
#  'scikit',
#  'learnorg',
#  'stable',
#  'modules',
#  'imputehtml',
#  'estimators',
#  'that',
#  'handle',
#  'nan',
#  'values',
#  '결측치',
#  '얘기인거',
#  '같은데',
#  '테스트파일도',
#  'train파일처럼',
#  '데이터',
#  '전처리',
#  '모델링',
#  '해야되나요',
#  'top',
#  'dfloc',
#  'df',
#  '자치구',
#  '중구',
#  '노선수',
#  'top',
#  'dfloc',
#  'df',
#  '자치구',
#  '동대문구',
#  '노선수',
#  'top',
#  'dfloc',
#  'df',
#  '자치구',
#  '관악구',
#  '노선수',
#  'spstf',
#  'oneway',
#  'top',
#  'top',
#  'top',
#  '실행하였는데',
#  'onewayResult',
#  'statistic',
#  'nan',
#  'pvalue',
#  'nan',
#  '이렇게만',
#  '결과가',
#  '떠서',
#  '원인을',
#  '모르겠어서',
#  '문의',
#  '드립니다',
#  '안녕하십니까',
#  '코딩마스터',
#  '표기',
#  '관련',
#  '질문드립니다',
#  '코딩',
#  '마스터스',
#  '기초',
#  '까지',
#  '풀었는데',
#  '문제란에서는',
#  '문제로',
#  '나오지만',
#  '문제',
#  '랭킹에는',
#  '제출',
#  '문제수',
#  '표기가',
#  '됩니다',
#  '제가',
#  '틀린',
#  '부분이',
#  '있다면',
#  '말씀해주시면',
#  '감사하겠습니다',
#  '좋은',
#  '하루',
#  '되십시오',
#  '실습',
#  '뭐만',
#  '남겨야',
#  '모델링에서',
#  '오류가',
#  '뜨나요',
#  '계속',
#  'fit만',
#  '오류가',
#  '발생합니다',
#  'train',
#  'test',
#  '잘못이',
#  '된건가요',
#  '실슴문제',
#  '더미',
#  '변수만드는',
#  '문제에서',
#  '더미변수를',
#  '만드는',
#  '것을',
#  '다시',
#  'df',
#  'total에',
#  '받아주는',
#  '것이',
#  '맞는지',
#  '문의드립니다',
#  '받으니까',
#  '뒤에',
#  '계속',
#  '더미변수로',
#  '나오게',
#  '되어서',
#  '확인차',
#  '문의드려요',
#  'min',
#  'samples',
#  'leaf',
#  'range',
#  'min',
#  'sample',
#  'split',
#  'range',
#  '두개의',
#  '내용과',
#  '차이점에',
#  '대해서',
#  '있을까요',
#  '첨부',
#  '드린',
#  '문제와',
#  '같이',
#  '리스트',
#  'n의',
#  '배수만',
#  '저장하는',
#  '것의',
#  '방법을',
#  '여쭙고',
#  '싶습니다',
#  '해당',
#  '이론',
#  '설명이',
#  '어디에',
#  '설명되어',
#  '있는',
#  '문의',
#  '드려도',
#  '될까요',
#  ...]

# %%
# 전체 단어 빈도수 카운트 하기
## Counter 함수를 사용하여 cleansing_word_list 변수에 포함된 각 단어의 빈도수를 산출하여 cleansing_word_count에 할당 합니다.

cleansing_word_count =

# %%
# 워드클라우드 만들기
## WordCloud 함수를 사용하여 각 단어의 빈도수가 저장되어 있는 cleansing_word_count 변수로 워드클라우드를 생성합니다.
## 생성하는 워드클라우드의 파라미터를 알맞게 조절 합니다.
## 워드클라우드 생성 매서드는 .generate_from_frequencies 를 사용합니다.
## <tip> 한 문의를 워드클라우드로 만들때는 generate 매서드 사용
## <tip> 각 단어와 빈도수를 가지고 워드클라우드를 만들때는 generate_from_frequencies 매서드 사용



cleansing_cloud = WordCloud(                              )
# Out:
# (-0.5, 499.5, 499.5, -0.5)

# %%
# 워드클라우드 비교하기
## 클렌징 전/후 워드클라우드를 한 그림으로 출력해서 어떤 차트가 더 효과적인지 비교해 보세요.

plt.figure(         )











plt.show()

# %% [markdown]
# ### <span style="color:green;background-color:#fff5b1"> [미션6] 교육 개선점 찾기</span>

# %% [markdown]
# 클렌징 한 워드클라우드와 단어 빈도수 카운트를 확인하여 교육생들이 어느부분을 자주 문의 하는지, 무엇을 어려워 하는지 파악 합니다.<br>
# 파악한 내용을 바탕으로 AIVLE스쿨이 어떤부분을 어떻게 개선하면 좋을지 시사점과 개선점을 도출하여 PPT에 정리해 보세요.
#
# * 개선점 도출
# * PPT 제작

# %% [markdown]
# ----------
# ----------

# %% [markdown]
# ### <span style="color:red;background-color:#fff5b1"> <도전미션> 문의유형 별 워드클라우드 생성 및 분야 개선점 찾기</span>

# %% [markdown]
# * 문의 유형별 워드클라우드를 한 그림에 표현해 주세요.
# * 각 워드클라우드 위에 title 를 달아 주세요.
#     * 타이틀: ['코드1', '코드2', '웹', '이론', '시스템 운영', '원격']
# * <도전미션>은 아래의 가이드 코드와 셀을 무시하고 자유롭게 코드를 작성하세요.

# %%
# Out:
# C:\Users\qicha\AppData\Local\Temp\ipykernel_5632\212322855.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   type_questions = pd.Series()
# C:\Users\qicha\AppData\Local\Temp\ipykernel_5632\212322855.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   type_questions = pd.Series()
# C:\Users\qicha\AppData\Local\Temp\ipykernel_5632\212322855.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   type_questions = pd.Series()
# C:\Users\qicha\AppData\Local\Temp\ipykernel_5632\212322855.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   type_questions = pd.Series()
# C:\Users\qicha\AppData\Local\Temp\ipykernel_5632\212322855.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   type_questions = pd.Series()
# C:\Users\qicha\AppData\Local\Temp\ipykernel_5632\212322855.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   type_questions = pd.Series()

# %% [markdown]
# ----------
# ----------

# %% [markdown]
# ----------

# %% [markdown]
# # 수고하셨습니다.

# %% [markdown]
# ----------
