# %% [markdown]
# # AIVLE스쿨 3기 DX트랙 5차 미니프로젝트 미션4,미션5 Training 용
# ## 사용자 웹/앱 프로토타입 및 대시보드 제작 Training

# %% [markdown]
# ## 1) 사전 준비 사항

# %% [markdown]
# * 프로토타입 제작을 위해 다음의 라이브러리 설치 필요
#     * streamlit : 웹 시각화 프레임 워크
#     * streamlit_folium : 지도 정보 시각화 웹 출력
#     * folium : 지도정보 시각화
#     * haversine : 위도/경도를 사용하여 거리 계산
#     * geopy : 거리주소 -> 위도/경도 변환
#     * joblib : ML 모델 저장 및 불러오기
#     * branca : 파이썬 코드 내 HTML + JS 사용
#     * plotly: 파이썬 데이터 시각화(챠트 출력)

# %%
# colab 사용시 그냥 설치

# !pip install streamlit
# !pip install streamlit_folium
# !pip install folium
# !pip install geopy
# !pip install haversine
# !pip install joblib
# !pip install plotly

# !pip install xgboost
# !pip install tensorflow

# %% [markdown]
# ## 2) streamlit으로 구현되는 프로토타입 실습
#
#  * 파일명은 training.py로 함

# %%
# %%writefile training.py

# 라이브러리 불러오기 

import pandas as pd
import numpy as np
import datetime
import joblib
from keras.models import load_model
from haversine import haversine
from urllib.parse import quote
import streamlit as st
from streamlit_folium import st_folium
import folium
import branca
from geopy.geocoders import Nominatim
import ssl
from urllib.request import urlopen
import pandas as pd
import plotly.express as px

# *********************** ▼ 가이드 코딩 Start ▼ ***********************

data = pd.read_csv('./119_emergency_dispatch_1.csv', encoding="cp949")

## 오늘 날짜
now_date = datetime.datetime.now(datetime.timezone.utc) + datetime.timedelta(hours=9)
now_date2 = datetime.datetime.strptime(now_date.strftime("%Y-%m-%d"), "%Y-%m-%d")

## 출동 이력의 최소 날짜, 최대 날짜
min_date = datetime.datetime.strptime("2023-01-01", "%Y-%m-%d")
max_date = datetime.datetime.strptime("2023-12-31", "%Y-%m-%d")
today_date = now_date.strftime("%Y-%m-%d")

## 레이아웃 구성하기 
st.set_page_config(layout="wide")



# *********************** ▲ 가이드 코딩 End ▲ ***********************
# *********************** ▼ 연습 코딩 Start ▼ ***********************




























# *********************** ▲ 연습 코딩 End ▲ ***********************
# Out:
# Overwriting training.py

# %% [markdown]
# ## 3) 프로토타입 확인하기

# %% [markdown]
# * dispatch_log.py 파일이 있는 디렉토리로 이동
# * 'Shift + 마우스 우클릭' -> '터미널에서 열기' 클릭
# * -> '터미널에서 열기'  메뉴가 없으면 '여기에 PowerShell 창 열기(S)' 클릭
# * 아래의 streamlit 실행( ! 빼고 실행)
# * training.py를 수정후 브라우저의 새로고침을 누르면 프로토타입에 자동 변경됨
# * 새로고침을 통해 변경사항 확인

# %%
# !streamlit run training.py
