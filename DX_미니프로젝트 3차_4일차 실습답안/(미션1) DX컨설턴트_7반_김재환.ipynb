# %% [markdown]
# # <span style="background-color:#fff5b1"><span style="color:black"><B>보험사 마케팅 활용을 위한 고객 군집화 모델링(정답지)

# %% [markdown]
# ## **Mission 1. 탐색적 데이터 분석**

# %% [markdown]
# ### **[미션 이해하기]**
# * 여러분들은 파인애플 보험사의 직원입니다. 파인애플 보험사는 효과적인 마케팅 전략을 완성시키기 위해 데이터 기반 마케팅을 시작했습니다.
#   <br>고객의 행동,성향, 니즈 등의 고객 데이터를 마케팅 전략에 반영하여 고객별로 적절한 마케팅 Action을 주는 미션을 받았습니다.
# * 고객별로 특징을 적절하게 반영할 수 있는 마케팅 방안은 고객을 segment 하는 것 인데, 어떤 방법으로 고객을 묶을 수 있을까요?
#   <br>바로, <font color="1E90FF"><b>군집분석을 기반으로 한 고객 segment를 개발 하는 것입니다.</font>

# %% [markdown]
# #### <b>[1일차] mission 1 목표 <b>: 고객의 기본 정보, 행동 정보 등을 확인해서 주요 변수를 선정하고 데이터 탐색해보기

# %% [markdown]
# #### <b>[실습프로세스]<b>

# %% [markdown]
# ![image.png](attachment:3c5b7601-3fca-4fe1-8b6b-5f23899f89b1.png)

# %% [markdown]
# ---------------------------------------------------------------------------------------------
# ## **(1) 데이터 불러오기**
#
# * numpy, pandas, matplotlib, seaborn 등 데이터 분석에 필요한 라이브러리를 로딩해 봅시다.
# * 만약 라이브러리가 없을 때 !pip를 통해 라이브러리를 설치해 주세요. (ex. !pip install pandas)
# * 현위치에서 'customers_seg.csv' 파일을 읽어와 주세요.
# * 활용하지 않는 변수를 index 화 해주세요.

# %%
# [같이 하기] 필요 라이브러리 로딩
# numpy, pandas, matplotlib, seaborn, os 를 임포트 하기

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# 시각화 표에서 에러나는 부분 글꼴 셋팅

plt.rc("font", family = "Malgun Gothic")
sns.set(font="Malgun Gothic", 
rc={"axes.unicode_minus":False}, style='white')

# %%
# [같이 하기] 데이터 불러오기
# 1. data 변수에 'customers_seg.csv' 파일을 불러와서 할당, 인코딩은 cp949로 하기
# 2. data 변수 호출해서 상위 5개 행 확인해보기

data = pd.read_csv('customers_seg.csv',encoding='cp949')
data.head()
# Out:
#    CID  AGE 등록(계/피) 고용상태  성별  Willingness to pay/Stay  갱신 상품타입  교육수준  \
# 0    1    3    피보험자   무직   1                 2.616381   0   기본  대학졸업
# 1    2    1     계약자   고용   0                 6.352530   0   기본  고졸이하
# 2    3    2     계약자   휴직   0                 4.974354   0   기본  대학졸업
# 3    4    5     계약자   고용   1                13.480284   0   고급  고졸이하
# 4    5    4     계약자   고용   0                 9.776436   0   기본    석사
#
#           소득  ... 결혼여부 월 납입액  VOC  타 상품 보유 현황 온라인방문빈도 갱신인센티브  판매채널    총지불금액  \
# 0          0  ...   미혼    80    0           1    자주방문     없음  자사영업   631000
# 1  102887400  ...   미혼    80    1         4이상     비방문    포인트   인터넷    54000
# 2   22159500  ...   기혼    60    0         4이상     비방문     할인  자사영업   362000
# 3   51562500  ...   기혼   110    0           2     비방문     할인  자사영업  1264000
# 4   26820200  ...   기혼   120    0           3     비방문     없음   대리점   947000
#
#     자동차 거주지사이즈
# 0  일반세단      소
# 1  일반세단      중
# 2  일반세단      중
# 3  컴팩트카      대
# 4   SUV      중
#
# [5 rows x 21 columns]

# %%
# [같이 하기] Index화 시키기
# 1. 해당 data 셋에서 'CID'는 활용하지 않을 예정으로 index 화 시켜보자.(함수: set_index 활용)
# 2. 잘 바뀌었는지 data 변수 호출해서 상위 5개 행 확인해보기

data = data.set_index('CID')
data.head()
# Out:
#      AGE 등록(계/피) 고용상태  성별  Willingness to pay/Stay  갱신 상품타입  교육수준         소득  \
# CID
# 1      3    피보험자   무직   1                 2.616381   0   기본  대학졸업          0
# 2      1     계약자   고용   0                 6.352530   0   기본  고졸이하  102887400
# 3      2     계약자   휴직   0                 4.974354   0   기본  대학졸업   22159500
# 4      5     계약자   고용   1                13.480284   0   고급  고졸이하   51562500
# 5      4     계약자   고용   0                 9.776436   0   기본    석사   26820200
#
#        지역 결혼여부  월 납입액  VOC 타 상품 보유 현황 온라인방문빈도 갱신인센티브  판매채널    총지불금액   자동차  \
# CID
# 1    도시근교   미혼     80    0          1    자주방문     없음  자사영업   631000  일반세단
# 2      시골   미혼     80    1        4이상     비방문    포인트   인터넷    54000  일반세단
# 3    도시근교   기혼     60    0        4이상     비방문     할인  자사영업   362000  일반세단
# 4    도시근교   기혼    110    0          2     비방문     할인  자사영업  1264000  컴팩트카
# 5    도시근교   기혼    120    0          3     비방문     없음   대리점   947000   SUV
#
#     거주지사이즈
# CID
# 1        소
# 2        중
# 3        중
# 4        대
# 5        중

# %% [markdown]
# ---------------------------------------------------------------------------------------------
# ## **(2) 데이터 기초 정보 확인하기**
# * 불러온 데이터셋(data)의 기초 정보들을 확인해봅시다.

# %%
# [문제1] 데이터 셋의 상위 5개 행을 확인해보자.

data.head()
# Out:
#      AGE 등록(계/피) 고용상태  성별  Willingness to pay/Stay  갱신 상품타입  교육수준         소득  \
# CID
# 1      3    피보험자   무직   1                 2.616381   0   기본  대학졸업          0
# 2      1     계약자   고용   0                 6.352530   0   기본  고졸이하  102887400
# 3      2     계약자   휴직   0                 4.974354   0   기본  대학졸업   22159500
# 4      5     계약자   고용   1                13.480284   0   고급  고졸이하   51562500
# 5      4     계약자   고용   0                 9.776436   0   기본    석사   26820200
#
#        지역 결혼여부  월 납입액  VOC 타 상품 보유 현황 온라인방문빈도 갱신인센티브  판매채널    총지불금액   자동차  \
# CID
# 1    도시근교   미혼     80    0          1    자주방문     없음  자사영업   631000  일반세단
# 2      시골   미혼     80    1        4이상     비방문    포인트   인터넷    54000  일반세단
# 3    도시근교   기혼     60    0        4이상     비방문     할인  자사영업   362000  일반세단
# 4    도시근교   기혼    110    0          2     비방문     할인  자사영업  1264000  컴팩트카
# 5    도시근교   기혼    120    0          3     비방문     없음   대리점   947000   SUV
#
#     거주지사이즈
# CID
# 1        소
# 2        중
# 3        중
# 4        대
# 5        중

# %%
# [문제2] 데이터 셋의 하위 5개 행을 확인해보자.

data.tail()
# Out:
#        AGE 등록(계/피) 고용상태  성별  Willingness to pay/Stay  갱신 상품타입  교육수준        소득  \
# CID
# 11996    1     계약자   고용   1                  25.9851   0   기본  대학졸업  86451000
# 11997    3    피보험자   고용   0                   3.4410   1   중급  대학졸업  25962000
# 11998    3    피보험자   무직   1                   9.0576   0   중급  대학졸업         0
# 11999    4     계약자   고용   1                   8.3472   0   중급  대학졸업  26366000
# 12000    3    피보험자   무직   1                   2.8971   0   중급  대학졸업         0
#
#          지역 결혼여부  월 납입액  VOC 타 상품 보유 현황 온라인방문빈도 갱신인센티브  판매채널   총지불금액   자동차  \
# CID
# 11996    도심   기혼     70    0          2     비방문  설계사독려   인터넷  245000  일반세단
# 11997  도시근교   미혼     80    0          1    자주방문     할인  자사영업  468000  일반세단
# 11998  도시근교   미혼     90    3          2    자주방문     할인  자사영업  977000  일반세단
# 11999  도시근교   기혼    100    0          3     비방문    포인트  자사영업  854000  일반세단
# 12000  도시근교   미혼     80    0          1    자주방문     없음   콜센터  456000  컴팩트카
#
#       거주지사이즈
# CID
# 11996      중
# 11997      중
# 11998      중
# 11999      대
# 12000      중

# %%
# [문제3] data 데이터프레임의 행, 열의 개수 확인해보자.(shape)

data.shape
# Out:
# (12000, 20)

# %%
#[문제4] data 데이터프레임의 컬럼명, 데이터 개수, 데이터 타입 정보를 확인 해보자.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12000 entries, 1 to 12000
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AGE                      12000 non-null  int64
#  1   등록(계/피)                  12000 non-null  object
#  2   고용상태                     12000 non-null  object
#  3   성별                       12000 non-null  int64
#  4   Willingness to pay/Stay  12000 non-null  float64
#  5   갱신                       12000 non-null  int64
#  6   상품타입                     12000 non-null  object
#  7   교육수준                     12000 non-null  object
#  8   소득                       12000 non-null  int64
#  9   지역                       12000 non-null  object
#  10  결혼여부                     12000 non-null  object
#  11  월 납입액                    12000 non-null  int64
#  12  VOC                      12000 non-null  int64
#  13  타 상품 보유 현황               12000 non-null  object
#  14  온라인방문빈도                  12000 non-null  object
#  15  갱신인센티브                   12000 non-null  object
#  16  판매채널                     12000 non-null  object
#  17  총지불금액                    12000 non-null  int64
#  18  자동차                      12000 non-null  object
#  19  거주지사이즈                   12000 non-null  object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 1.9+ MB

# %%
# [문제5] 데이터 셋 수치형 데이터 기초통계 정보를 확인해보자

data.describe()
# Out:
#                 AGE            성별  Willingness to pay/Stay            갱신  \
# count  12000.000000  12000.000000             12000.000000  12000.000000
# mean       3.079000      0.487583                 8.859478      0.143000
# std        1.121768      0.499867                 7.698885      0.350087
# min        1.000000      0.000000                 2.045730      0.000000
# 25%        3.000000      0.000000                 4.373400      0.000000
# 50%        3.000000      0.000000                 6.384831      0.000000
# 75%        4.000000      1.000000                 9.867900      0.000000
# max        6.000000      1.000000                92.496300      1.000000
#
#                  소득         월 납입액           VOC         총지불금액
# count  1.200000e+04  12000.000000  12000.000000  1.200000e+04
# mean   4.641737e+07    100.065833      0.390167  5.355854e+05
# std    3.736221e+07     42.453750      0.919605  3.587993e+05
# min    0.000000e+00     60.000000      0.000000  0.000000e+00
# 25%    0.000000e+00     70.000000      0.000000  3.360000e+05
# 50%    4.186240e+07     90.000000      0.000000  4.740000e+05
# 75%    7.664150e+07    120.000000      0.000000  6.790000e+05
# max    1.320209e+08    350.000000      5.000000  3.573000e+06

# %%
# [문제6] 데이터 셋의 모든 컬럼명(변수명)을 확인해보자.

data.columns
# Out:
# Index(['AGE', '등록(계/피)', '고용상태', '성별', 'Willingness to pay/Stay', '갱신', '상품타입',
#        '교육수준', '소득', '지역', '결혼여부', '월 납입액', 'VOC', '타 상품 보유 현황', '온라인방문빈도',
#        '갱신인센티브', '판매채널', '총지불금액', '자동차', '거주지사이즈'],
#       dtype='object')

# %% [markdown]
# ---------------------------------------------------------------------------------------------
# ## **(3) 주요 변수 선정 및 탐색**

# %% [markdown]
# #### <b> 21개의 features 값은 어떤 의미일지 알아보고 주요 변수를 선정해 봅시다!
# ![image.png](attachment:image.png)

# %% [markdown]
# ---------------------------------------------------------------------------------------------
# ### *<b>이 중 주요 변수를 선정 해 보았을 때 <font color="1E90FF"><b>11개의 features를 선정하였다.</font>
# #### <font color="1E90FF"><b>* 우리의 목표: 군집화가 된 고객 segment 개발</font>
#
# <span><b>1. 도메인 내 주요 정보 항목</span>
#     <br><br>
#         - (1) Willingness to pay/Stay: 계속 보험을 유지할 지 판단하는 지표 (신용점수, 납부/연체기록, 소득 등 활용)
#     <br>- (2) 소득
#     <br>- (3) 월 납입액
#     <br>- (4) 타상품 보유 현황: 고객이 이용하는 파인애플사의 타 서비스 수(어느정도 고객의 충성도를 알 수 있음)
#     <br>- (5) 총지불금액
#
# <span><b>2. 분석가 선정 컬럼</span>
#     <br><br>- (6)AGE, (7)고용상태, (8)교육수준: 고객 기본 정보
#     <br>- (9)상품타입, (10)거주지사이즈, (11)자동차: 소득 등과 연관해서 추정이 가능한 정보

# %% [markdown]
# ### <b> [분석가 선정 컬럼 탐색하기]
# * 분석가 선정 컬럼 : AGE, 고용상태, 교육수준, 상품 타입, 거주지사이즈, 자동차(총 6개 피쳐)
# * 위 분석가 선정 컬럼을 crosstab을 통해서 탐색해 보자!

# %%
#[문제 7] 분석가 선정 컬럼들이 수치형인지 문자/범주형인지 알아보자! (info 활용)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12000 entries, 1 to 12000
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AGE                      12000 non-null  int64
#  1   등록(계/피)                  12000 non-null  object
#  2   고용상태                     12000 non-null  object
#  3   성별                       12000 non-null  int64
#  4   Willingness to pay/Stay  12000 non-null  float64
#  5   갱신                       12000 non-null  int64
#  6   상품타입                     12000 non-null  object
#  7   교육수준                     12000 non-null  object
#  8   소득                       12000 non-null  int64
#  9   지역                       12000 non-null  object
#  10  결혼여부                     12000 non-null  object
#  11  월 납입액                    12000 non-null  int64
#  12  VOC                      12000 non-null  int64
#  13  타 상품 보유 현황               12000 non-null  object
#  14  온라인방문빈도                  12000 non-null  object
#  15  갱신인센티브                   12000 non-null  object
#  16  판매채널                     12000 non-null  object
#  17  총지불금액                    12000 non-null  int64
#  18  자동차                      12000 non-null  object
#  19  거주지사이즈                   12000 non-null  object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 1.9+ MB

# %% [markdown]
# ### **【각각의 변수들이 어떤 의미를 가지고 있을지 데이터 탐색을 해보자!】**

# %% [markdown]
# <b>1. AGE

# %%
#[같이 하기] age 변수에 대해 교차표를 생성하고 탐색해보자.
#  age는 수치형이나 연령대(20대, 30대...)이므로 교차표(crosstab) 생성해보자.
#  crosstab의 파라미터(data[],columns='percentage',normalize= ) 하고 비율로 바꿔보자.
#  (1: 20대, 2: 30대, 3: 40대, 4: 50대, 5: 60대, 6: 70대)

pd.crosstab(data['AGE'],columns='percentage',normalize=True)*100
# Out:
# col_0  percentage
# AGE
# 1       12.116667
# 2       12.816667
# 3       39.791667
# 4       26.033333
# 5        8.808333
# 6        0.433333

# %% [markdown]
# <b>**age 변수에 대해 간단하게 탐색한 내용을 아래 주석으로 적어보자!**
# ## ↓

# %%
# 연령대를 보았을 때 약 40% 정도가 40대 임을 알 수 있다. 약 4~50대가 65% 정도이다.

# %%
#[같이 하기] age에 대해 countplot 으로 시각화를 해보자!
# 1. sns.countplot(x=' ', data= )으로 시각화. 색상은 원하는 색상으로!
# 2. title=('age'), grid 도 넣어서 이쁘게 만들어보자.

sns.countplot(x='AGE',data=data,palette='cool')
plt.title('age')
plt.grid()
plt.show()

# %% [markdown]
# <b>2. 고용상태

# %%
#[문제 8] '고용상태' 변수에 대해 교차표를 생성하고 탐색해보자.(함수: crosstab(),colums='count')

pd.crosstab(data['고용상태'],columns='count')
# Out:
# col_0  count
# 고용상태
# FALSE    360
# 고용      7518
# 무직      3028
# 휴직      1094

# %%
#[문제 9] 생성한 교차표를 비율로 만들어서 탐색해보자.
# Normalize=True(표준화) 하고 * 100을 곱해주어 비율을 확인 해보자.

pd.crosstab(data['고용상태'],columns='percentage',normalize=True) * 100
# Out:
# col_0  percentage
# 고용상태
# FALSE    3.000000
# 고용      62.650000
# 무직      25.233333
# 휴직       9.116667

# %%
#[문제 10] 결측치 같아 보이는 것을 확인 해보자.
# 어라.. FALSE 값이 있잖어? 이게 뭐여...결측치가 있네?....info 값에서는 결측치가 안보였는데...?
# 고용상태의 결측치가 있는지 다시 확인해 보자.(isnull().any() 활용)

data[['고용상태']].isnull().any()
# Out:
# 고용상태    False
# dtype: bool

# %% [markdown]
# <b>**'고용상태' 변수에 대해 간단하게 탐색한 내용을 아래 주석으로 적어보자!**
# ## ↓

# %%
#고용상태인 사람이 62%로 가장 많았다. 무직과 휴직은 30% 정도다. false 값은 미확인된 값으로 크게 유의미하지 않는다.

# %%
#[문제 11] '고용상태'에 대해 countplot 으로 시각화를 해보자!

sns.countplot(x='고용상태',data=data,palette='cool')
plt.grid()
plt.show()

# %% [markdown]
# <b>3. 교육수준

# %%
#[문제 12] '교육수준' 변수에 대해 교차표를 생성하고 탐색해보자.(함수: crosstab(),colums='count')

pd.crosstab(data['교육수준'],columns='count')
# Out:
# col_0  count
# 교육수준
# 고졸이하    3477
# 대학졸업    7105
# 박사       439
# 석사       979

# %%
#[문제 13] 교육수준별 생성한 교차표를 비율로 만들어서 탐색해보자.
# Normalize=True(표준화) 하고 * 100을 곱해주어 비율을 확인 해보자.

pd.crosstab(data['교육수준'],columns='percentage',normalize=True)*100
# Out:
# col_0  percentage
# 교육수준
# 고졸이하    28.975000
# 대학졸업    59.208333
# 박사       3.658333
# 석사       8.158333

# %% [markdown]
# <b>**'교육수준' 변수에 대해 간단하게 탐색한 내용을 아래 주석으로 적어보자!**
# ## ↓

# %%
# 약 60% 이상이 대학졸업자 이고, 약 석/박사는 12%정도 이다

# %%
#[문제 14] '교육수준'에 대해 countplot 으로 시각화를 해보자!

sns.countplot(x='교육수준',data=data,palette='cool')
plt.grid()
plt.show()

# %% [markdown]
# <b>4. 상품타입

# %%
#[문제 15] '상품타입'변수에 대해 교차표를 생성하고 탐색해보자.(함수: crosstab(),colums='percentage')
# Normalize=True(표준화) 하고 * 100을 곱해주어 비율을 확인 해보자.

pd.crosstab(data['상품타입'],columns='percentage',normalize=True)*100
# Out:
# col_0  percentage
# 상품타입
# 고급       8.958333
# 기본      60.650000
# 중급      30.391667

# %% [markdown]
# <b>**'상품타입' 변수에 대해 간단하게 탐색한 내용을 아래 주석으로 적어보자!**
# ## ↓

# %%
# 90% 이상 상품 타입은 기본 또는 중급이며, 10% 미만으로 고급 수준으로 가입. 고객을 그룹핑 할 때 필요할 것 같다.

# %%
#[문제 16] '상품타입'에 대해 countplot 으로 시각화를 해보자!

sns.countplot(x='상품타입',data=data,palette='cool')
plt.grid()
plt.show()

# %% [markdown]
# <b>5. 거주지사이즈

# %%
#[문제 17]'거주지사이즈'변수에 대해 교차표를 생성하고 탐색해보자.(함수: crosstab(),colums='percentage')
# Normalize=True(표준화) 하고 * 100을 곱해주어 비율을 확인 해보자.

pd.crosstab(data['거주지사이즈'],columns='percentage',normalize=True)*100
# Out:
# col_0   percentage
# 거주지사이즈
# 대        10.375000
# 소        19.433333
# 중        70.191667

# %% [markdown]
# <b>**'거주지사이즈' 변수에 대해 간단하게 탐색한 내용을 아래 주석으로 적어보자!**
# ## ↓

# %%
# 거주지 사이즈는 중이 70%로 가장 많은 비율이고 90정도는 소,중으로 보여짐. 대는 별로 없음.

# %%
#[문제 18] '거주지사이즈'에 대해 countplot 으로 시각화를 해보자!

sns.countplot(x='거주지사이즈',data=data,palette='cool')
plt.grid()
plt.show()

# %% [markdown]
# <b>6. 자동차

# %%
#[문제 19]'자동차'변수에 대해 교차표를 생성하고 탐색해보자.(함수: crosstab(),colums='percentage')
# Normalize=True(표준화) 하고 * 100을 곱해주어 비율을 확인 해보자.

pd.crosstab(data['자동차'],columns='percentage',normalize=True)*100
# Out:
# col_0  percentage
# 자동차
# SUV     19.466667
# 고급차      3.783333
# 스포츠카     5.433333
# 일반세단    50.616667
# 컴팩트카    20.700000

# %% [markdown]
# <b>**'자동차' 변수에 대해 간단하게 탐색한 내용을 아래 주석으로 적어보자!**
# ## ↓

# %%
# 반 이상(50% 이상) 일반 세단을 타고 있고, 고급차 및 스포츠카는 약 9% 정도( 소득과 연계관계를 확인 할 수 있음)

# %%
#[문제 20]'자동차'에 대해 countplot 으로 시각화를 해보자!

sns.countplot(x='자동차',data=data,palette='cool')
plt.grid()
plt.show()

# %% [markdown]
# ### **<b>[도메인 주요 항목 컬럼 탐색하기]**
# * 도메인 주요 항목 : Willingness to pay/Stay,소득,월 납입액,타상품 보유 현황,총지불금액(총 5개 항목)
# * 위 도메인 주요 항목 컬럼을 crosstab, histplot 을 통해서 탐색해 보자

# %%
#[문제 21] 도메인 내 주요 항목 컬럼들이 수치형인지 문자형인지 알아보자! (info 활용)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12000 entries, 1 to 12000
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AGE                      12000 non-null  int64
#  1   등록(계/피)                  12000 non-null  object
#  2   고용상태                     12000 non-null  object
#  3   성별                       12000 non-null  int64
#  4   Willingness to pay/Stay  12000 non-null  float64
#  5   갱신                       12000 non-null  int64
#  6   상품타입                     12000 non-null  object
#  7   교육수준                     12000 non-null  object
#  8   소득                       12000 non-null  int64
#  9   지역                       12000 non-null  object
#  10  결혼여부                     12000 non-null  object
#  11  월 납입액                    12000 non-null  int64
#  12  VOC                      12000 non-null  int64
#  13  타 상품 보유 현황               12000 non-null  object
#  14  온라인방문빈도                  12000 non-null  object
#  15  갱신인센티브                   12000 non-null  object
#  16  판매채널                     12000 non-null  object
#  17  총지불금액                    12000 non-null  int64
#  18  자동차                      12000 non-null  object
#  19  거주지사이즈                   12000 non-null  object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 1.9+ MB

# %% [markdown]
# <b> 1. WTP(Willingness to pay/Stay)
# * 연속형/수치형 컬럼이기 때문에 histplot으로 데이터 확인해보기

# %%
#[같이 하기] 히스토그램으로 'Willingness to pay/Stay(WTP)'에 대한 그래프를 그려보자.

# 1. figsize(12,8) 셋팅하기

plt.figure(figsize=(12,8))
plt.subplot(2,1,1)

# 2. histplot 그리기
# bins = 30, kde = True로 설정해서 그래프를 그려보자.

sns.histplot(data['Willingness to pay/Stay'],bins=30,kde=True)
plt.grid()
plt.show()

# %%
#[같이 하기] WTP의 평균값을 확인해보자(describe 사용)

data.describe()
# Out:
#                 AGE            성별  Willingness to pay/Stay            갱신  \
# count  12000.000000  12000.000000             12000.000000  12000.000000
# mean       3.079000      0.487583                 8.859478      0.143000
# std        1.121768      0.499867                 7.698885      0.350087
# min        1.000000      0.000000                 2.045730      0.000000
# 25%        3.000000      0.000000                 4.373400      0.000000
# 50%        3.000000      0.000000                 6.384831      0.000000
# 75%        4.000000      1.000000                 9.867900      0.000000
# max        6.000000      1.000000                92.496300      1.000000
#
#                  소득         월 납입액           VOC         총지불금액
# count  1.200000e+04  12000.000000  12000.000000  1.200000e+04
# mean   4.641737e+07    100.065833      0.390167  5.355854e+05
# std    3.736221e+07     42.453750      0.919605  3.587993e+05
# min    0.000000e+00     60.000000      0.000000  0.000000e+00
# 25%    0.000000e+00     70.000000      0.000000  3.360000e+05
# 50%    4.186240e+07     90.000000      0.000000  4.740000e+05
# 75%    7.664150e+07    120.000000      0.000000  6.790000e+05
# max    1.320209e+08    350.000000      5.000000  3.573000e+06

# %% [markdown]
# <b>**'Willingness to pay/Stay(WTP)' 변수에 대해 간단하게 탐색한 내용을 아래 주석으로 적어보자!**
# ## ↓

# %%
# 대부분의 고객의 경우 보험유지기대지표(WTP)의 값이 낮게 나옴(0~10정도 사이가 대부분)
# 평균값을 확인해보니 8 정도로 낮은 것으로 알 수 있음.

# %% [markdown]
# <b> 2. 소득
# * 연속형/수치형 컬럼이기 때문에 histplot으로 데이터 확인해보기

# %%
#[문제 22] 히스토그램으로 '소득'에 대한 그래프를 그려보자.
# bins = 30, kde = True로 설정해서 한번 보자

# 1. figsize(12,8) 셋팅하기
plt.figure(figsize=(12,8))
plt.subplot(2,1,1)

# 2. histplot 그리기
# bins = 30, kde = True로 설정해서 그래프를 그려보자.
sns.histplot(data['소득'],bins=30,kde=True)
plt.grid()
plt.show()

# %% [markdown]
# <b>**'소득' 변수에 대해 간단하게 탐색한 내용을 아래 주석으로 적어보자!**
# ## ↓

# %%
# 소득이 아예 없는 고객이 상당히 많고, 나머지는 고루 분포되어 있는 것 같다.
# 왜, 소득이 아예 없는 고객이 많은지는 아래 내용으로 판단해봐야할 것 같다.

# 소득 정보를 확인하기 위해서 소득 정보를 입력해 달라고 하는 것이 보통인데 현재 고객이 직접 입력하거나, 보험 설계사가
# 입력을 할 때 오류가 많이 생기는 현상 발생한 것 같다.
# 해서 데이터의 신뢰성에 문제가 있을 것 같고, 데이터에 다른 부차원적인 데이터를 가지고 와서 정제하여 판단이 필요할것 같다.

# %% [markdown]
# <b> 3. 월 납입액
# * 연속형/수치형 컬럼이기 때문에 histplot으로 데이터 확인해보기

# %%
#[문제 23] 히스토그램으로 '월 납입액'에 대한 그래프를 그려보자.
# bins = 30, kde = True로 설정해서 한번 보자

# 1. figsize(12,8) 셋팅하기
plt.figure(figsize=(12,8))
plt.subplot(2,1,1)

# 2. histplot 그리기
# bins = 30, kde = True로 설정해서 그래프를 그려보자.
sns.histplot(data['월 납입액'],bins=30,kde=True)
plt.grid()
plt.show()

# %%
#[문제 24] '월 납입액'의 평균값을 확인해보자(describe 사용)
data.describe()
# Out:
#                 AGE            성별  Willingness to pay/Stay            갱신  \
# count  12000.000000  12000.000000             12000.000000  12000.000000
# mean       3.079000      0.487583                 8.859478      0.143000
# std        1.121768      0.499867                 7.698885      0.350087
# min        1.000000      0.000000                 2.045730      0.000000
# 25%        3.000000      0.000000                 4.373400      0.000000
# 50%        3.000000      0.000000                 6.384831      0.000000
# 75%        4.000000      1.000000                 9.867900      0.000000
# max        6.000000      1.000000                92.496300      1.000000
#
#                  소득         월 납입액           VOC         총지불금액
# count  1.200000e+04  12000.000000  12000.000000  1.200000e+04
# mean   4.641737e+07    100.065833      0.390167  5.355854e+05
# std    3.736221e+07     42.453750      0.919605  3.587993e+05
# min    0.000000e+00     60.000000      0.000000  0.000000e+00
# 25%    0.000000e+00     70.000000      0.000000  3.360000e+05
# 50%    4.186240e+07     90.000000      0.000000  4.740000e+05
# 75%    7.664150e+07    120.000000      0.000000  6.790000e+05
# max    1.320209e+08    350.000000      5.000000  3.573000e+06

# %% [markdown]
# <b>**'월 납입액' 변수에 대해 간단하게 탐색한 내용을 아래 주석으로 적어보자!**
# ## ↓

# %%
# 월 납입액은 60~100 사이가 많으며, 평균은 100으로 평균보다 납입액이 작은 사람들이 많은 것 같다.

# %% [markdown]
# <b> 4. 타상품 보유
# * 문자형/범주형 컬럼이기 때문에 crosstab으로 데이터 확인해보기

# %%
#[문제 25] '타상품 보유' 변수에 대해 교차표를 생성하고 탐색해보자.(함수: crosstab(),colums='percentage')
# Normalize=True(표준화) 하고 * 100을 곱해주어 비율을 확인 해보자.

pd.crosstab(data['타 상품 보유 현황'],columns='percentage',normalize=True)*100
# Out:
# col_0       percentage
# 타 상품 보유 현황
# 1            35.691667
# 2            25.141667
# 3            12.875000
# 4이상          26.291667

# %% [markdown]
# <b>**'타상품 보유' 변수에 대해 간단하게 탐색한 내용을 아래 주석으로 적어보자!**
# ## ↓

# %%
# 대부분 1~2개 정도이나
# 생각보다 4개 이상의 타 상품을 보유하고 있는 고객도 26~27% 정도 존재해서 회사 상품에 충성도가 높은 고객이 꽤 있다는 것을 생각해 볼 수 있다.
# 아니면 연계 상품으로 최소 1개가 같이 들어가는 것일지 예측 해볼 수 있을 것 같다.(타상품 보유 현황이 0 이 없는 것으로 추정)

# %% [markdown]
# <b> 5. 총지불금액
# * 연속형/수치형 컬럼이기 때문에 histplot으로 데이터 확인해보기

# %%
#[문제 26] 히스토그램으로 '총지불금액'에 대한 그래프를 그려보자.
# bins = 30, kde = True로 설정해서 한번 보자

# 1. figsize(12,8) 셋팅하기
plt.figure(figsize=(12,8))
plt.subplot(2,1,1)

# 2. histplot 그리기
# bins = 30, kde = True로 설정해서 그래프를 그려보자.
sns.histplot(data['총지불금액'],bins=30,kde=True)
plt.grid()
plt.show()

# %%
#[문제 27] '총지불금액'의 평균값을 확인해보자(describe 사용)

data.describe()
# Out:
#                 AGE            성별  Willingness to pay/Stay            갱신  \
# count  12000.000000  12000.000000             12000.000000  12000.000000
# mean       3.079000      0.487583                 8.859478      0.143000
# std        1.121768      0.499867                 7.698885      0.350087
# min        1.000000      0.000000                 2.045730      0.000000
# 25%        3.000000      0.000000                 4.373400      0.000000
# 50%        3.000000      0.000000                 6.384831      0.000000
# 75%        4.000000      1.000000                 9.867900      0.000000
# max        6.000000      1.000000                92.496300      1.000000
#
#                  소득         월 납입액           VOC         총지불금액
# count  1.200000e+04  12000.000000  12000.000000  1.200000e+04
# mean   4.641737e+07    100.065833      0.390167  5.355854e+05
# std    3.736221e+07     42.453750      0.919605  3.587993e+05
# min    0.000000e+00     60.000000      0.000000  0.000000e+00
# 25%    0.000000e+00     70.000000      0.000000  3.360000e+05
# 50%    4.186240e+07     90.000000      0.000000  4.740000e+05
# 75%    7.664150e+07    120.000000      0.000000  6.790000e+05
# max    1.320209e+08    350.000000      5.000000  3.573000e+06

# %% [markdown]
# <b>**'총 지불 금액' 변수에 대해 간단하게 탐색한 내용을 아래 주석으로 적어보자!**
# ## ↓

# %%
# 총 지불금액은 WTP와 같이 왼쪽으로 치우쳐져 있어 총 지불금액이 작은 걸로 나타나져 있는 것 같다.
# 일부 고객들은 총 지불금액이 많이 높은 것으로 확인 되기도 한다.

# %% [markdown]
# ## **[Mission 1-변수 탐색 결론]**
#
# * 수치형 컬럼 이외에도, 주요 변수 중 object 형태의 컬럼이 존재
# * 수치형 컬럼은 단위가 각각 다르므로 스케일링 고려 필요
# * 범주형 컬럼은 인코딩을 통해서 모델링을 위한 변환이 필요

# %% [markdown]
# ### <font color="1E90FF"><b>→ 데이터를 확인하고 탐색하여 전처리의 방향성 및 feature 값에 대한 이해 증대<b><br>

# %% [markdown]
# # <b>Mission 1 완료!
# 수고하셨습니다!
