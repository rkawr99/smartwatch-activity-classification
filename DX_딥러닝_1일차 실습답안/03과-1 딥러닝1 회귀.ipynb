# %% [markdown]
# # 딥러닝1 : 회귀

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 학습곡선 그래프

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv'
data = pd.read_csv(path)
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# |	변수	|	설명	|
# |	----	|	----	|
# |	medv	|	타운별 집값(중위수)	|
# |	crim	|	범죄율	|
# |	zn	|	25,000 평방피트를 초과 거주지역 비율	|
# |	indus	|	비소매상업지역 면적 비율	|
# |	chas	|	찰스강변 위치(범주 : 강변1, 아니면 0)	|
# |	nox	|	일산화질소 농도	|
# |	rm	|	주택당 방 수	|
# |	age	|	1940년 이전에 건축된 주택의 비율	|
# |	dis	|	직업센터의 거리	|
# |	rad	|	방사형 고속도로까지의 거리	|
# |	tax	|	재산세율	|
# |	ptratio	|	학생/교사 비율	|
# |	lstat	|	인구 중 하위 계층 비율	|

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# lstat, ptratio, crim 만 이용하여 medv를 예측하는 모델을 만들어 봅시다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (1) 데이터 준비
# * x, y 나누기
#     * x : lstat, ptratio, crim
#     * y : medv

# %%
target = 'medv'
features = ['lstat', 'ptratio', 'crim']
x = data.loc[:, features]
y = data.loc[:, target]

# %% [markdown]
# ### (2) NaN 조치

# %% [markdown]
# ### (3) 가변수화

# %% [markdown]
# ### (4) 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# ### (5) Scaling

# %%
# 스케일러 선언
scaler = MinMaxScaler()

# train 셋으로 fitting & 적용
x_train = scaler.fit_transform(x_train)

# validation 셋은 적용만!
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.딥러닝1 : 3개의 feature

# %% [markdown]
# ### (1) 모델설계

# %%
# 분석단위의 shape
nfeatures = x_train.shape[1] #num of columns
nfeatures
# Out:
# 3

# %%
# 메모리 정리
clear_session()

# Sequential 타입 
model = Sequential( Dense(1, input_shape = (nfeatures,)) )

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * compile
#     * optimizer = 'adam'    : 기본값으로 옵티마이저 사용(learning_rate = 0.001)
#     * optimizer = Adam(lr = 0.1) : 옵션 값 조정 가능
#         * lr과 learning_rate은 같지만, learning_rate 사용을 권장

# %%
model.compile(optimizer = Adam(learning_rate = 0.1), loss = 'mse')

# %% [markdown]
# ### (2) 학습

# %% [markdown]
# validation_split=0.2 : 학습시, 학습용 데이터에서 0.2 만큼 떼어 내서 검증셋으로 활용

# %%
history = model.fit(x_train, y_train, 
                    epochs = 20, validation_split=0.2).history
# Out:
# Epoch 1/20
# 11/11 [==============================] - 1s 28ms/step - loss: 573.6552 - val_loss: 579.1285
# Epoch 2/20
# 11/11 [==============================] - 0s 7ms/step - loss: 490.3806 - val_loss: 500.3945
# Epoch 3/20
# 11/11 [==============================] - 0s 7ms/step - loss: 418.8752 - val_loss: 433.4019
# Epoch 4/20
# 11/11 [==============================] - 0s 5ms/step - loss: 358.8882 - val_loss: 377.5435
# Epoch 5/20
# 11/11 [==============================] - 0s 5ms/step - loss: 310.1695 - val_loss: 333.8667
# Epoch 6/20
# 11/11 [==============================] - 0s 4ms/step - loss: 271.8309 - val_loss: 298.4194
# Epoch 7/20
# 11/11 [==============================] - 0s 5ms/step - loss: 240.9803 - val_loss: 268.8591
# Epoch 8/20
# 11/11 [==============================] - 0s 5ms/step - loss: 216.5403 - val_loss: 247.7724
# Epoch 9/20
# 11/11 [==============================] - 0s 6ms/step - loss: 199.0551 - val_loss: 230.8531
# Epoch 10/20
# 11/11 [==============================] - 0s 5ms/step - loss: 184.8725 - val_loss: 217.6968
# Epoch 11/20
# 11/11 [==============================] - 0s 6ms/step - loss: 174.0716 - val_loss: 206.8150
# Epoch 12/20
# 11/11 [==============================] - 0s 7ms/step - loss: 165.6062 - val_loss: 198.2230
# Epoch 13/20
# 11/11 [==============================] - 0s 6ms/step - loss: 158.8497 - val_loss: 191.6872
# Epoch 14/20
# 11/11 [==============================] - 0s 6ms/step - loss: 153.0523 - val_loss: 185.5318
# Epoch 15/20
# 11/11 [==============================] - 0s 4ms/step - loss: 148.0902 - val_loss: 179.9606
# Epoch 16/20
# 11/11 [==============================] - 0s 6ms/step - loss: 143.7668 - val_loss: 175.3720
# Epoch 17/20
# 11/11 [==============================] - 0s 5ms/step - loss: 139.8639 - val_loss: 170.9184
# Epoch 18/20
# 11/11 [==============================] - 0s 5ms/step - loss: 136.4142 - val_loss: 167.1482
# Epoch 19/20
# 11/11 [==============================] - 0s 5ms/step - loss: 133.3163 - val_loss: 163.7343
# Epoch 20/20
# 11/11 [==============================] - 0s 6ms/step - loss: 130.3839 - val_loss: 160.1822

# %% [markdown]
# * 학습결과 그래프

# %%
# 함수로 만들어서 사용합시다.
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %%
dl_history_plot(history)

# %% [markdown]
# ### (3) 예측 및 검증

# %%
pred = model.predict(x_val)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
print(f'RMSE : {mean_squared_error(y_val, pred, squared=False)}')
print(f'MAE  : {mean_absolute_error(y_val, pred)}')
print(f'MAPE : {mean_absolute_percentage_error(y_val, pred)}')
# Out:
# RMSE : 9.669708403020202
# MAE  : 6.433950388665293
# MAPE : 0.33602218424196195

# %% [markdown]
# ## 4.딥러닝2 : 전체 feature
# * 이제 전체 데이터를 가지고 모델링을 시도해 보겠습니다.

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 분할

# %%
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:, target]
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
nfeatures = x_train.shape[1]
nfeatures
# Out:
# 12

# %%
# 메모리 정리
clear_session()

# Sequential 타입 모델 선언
model2 = Sequential( Dense( 1 , input_shape = (nfeatures, ) ) )

# 모델요약
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 13
#
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * compile

# %%
model2.compile( optimizer= 'adam', loss = 'mse' )

# %% [markdown]
# * 학습

# %%
history = model2.fit(x_train, y_train, epochs = 20, validation_split= 0.2 ).history
# Out:
# Epoch 1/20
# 11/11 [==============================] - 1s 16ms/step - loss: 565.5616 - val_loss: 621.3331
# Epoch 2/20
# 11/11 [==============================] - 0s 5ms/step - loss: 563.2854 - val_loss: 618.9451
# Epoch 3/20
# 11/11 [==============================] - 0s 6ms/step - loss: 560.9579 - val_loss: 616.5770
# Epoch 4/20
# 11/11 [==============================] - 0s 7ms/step - loss: 558.7114 - val_loss: 614.2589
# Epoch 5/20
# 11/11 [==============================] - 0s 8ms/step - loss: 556.4814 - val_loss: 611.9671
# Epoch 6/20
# 11/11 [==============================] - 0s 8ms/step - loss: 554.2977 - val_loss: 609.6714
# Epoch 7/20
# 11/11 [==============================] - 0s 6ms/step - loss: 552.0700 - val_loss: 607.4025
# Epoch 8/20
# 11/11 [==============================] - 0s 6ms/step - loss: 549.9083 - val_loss: 605.1164
# Epoch 9/20
# 11/11 [==============================] - 0s 6ms/step - loss: 547.7079 - val_loss: 602.8388
# Epoch 10/20
# 11/11 [==============================] - 0s 6ms/step - loss: 545.4985 - val_loss: 600.5602
# Epoch 11/20
# 11/11 [==============================] - 0s 6ms/step - loss: 543.2903 - val_loss: 598.2167
# Epoch 12/20
# 11/11 [==============================] - 0s 6ms/step - loss: 541.0563 - val_loss: 595.9559
# Epoch 13/20
# 11/11 [==============================] - 0s 7ms/step - loss: 538.8772 - val_loss: 593.7271
# Epoch 14/20
# 11/11 [==============================] - 0s 7ms/step - loss: 536.7662 - val_loss: 591.5128
# Epoch 15/20
# 11/11 [==============================] - 0s 6ms/step - loss: 534.6406 - val_loss: 589.2813
# Epoch 16/20
# 11/11 [==============================] - 0s 6ms/step - loss: 532.4768 - val_loss: 587.0484
# Epoch 17/20
# 11/11 [==============================] - 0s 5ms/step - loss: 530.3429 - val_loss: 584.8632
# Epoch 18/20
# 11/11 [==============================] - 0s 5ms/step - loss: 528.2234 - val_loss: 582.6536
# Epoch 19/20
# 11/11 [==============================] - 0s 5ms/step - loss: 526.1087 - val_loss: 580.4438
# Epoch 20/20
# 11/11 [==============================] - 0s 5ms/step - loss: 524.0059 - val_loss: 578.2699

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# * 예측 및 평가

# %%
pred2 = model2.predict(x_val)
print(f'RMSE : {mean_squared_error(y_val, pred2, squared=False)}')
print(f'MAE  : {mean_absolute_error(y_val, pred2)}')
print(f'MAPE : {mean_absolute_percentage_error(y_val, pred2)}')
# Out:
# 4/4 [==============================] - 0s 5ms/step
# RMSE : 21.505661013958466
# MAE  : 19.858213945697333
# MAPE : 0.8997004934079403

# %% [markdown]
# ## 5.실습!
# * 위 4번에 이어서, 여러분은 다음을 조절할 수 있습니다.
#     * epochs(반복횟수), learning_rate(학습율)
# * 4번 코드를 그대로 보면서 작성하고 위 두가지를 조절하며 성능을 높여봅시다!

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 분할

# %%
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:, target]
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
nfeatures = x_train.shape[1]
nfeatures
# Out:
# 3

# %%
clear_session()
model3 = Sequential( Dense( 1  , input_shape = (nfeatures, ) )  )
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * compile

# %%
model3.compile(optimizer = Adam( learning_rate = 0.1 ), loss = 'mse'  )

# %% [markdown]
# * 학습

# %%
hist = model3.fit(x_train, y_train, epochs = 50, validation_split= .2).history
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 20ms/step - loss: 571.8422 - val_loss: 577.5515
# Epoch 2/50
# 11/11 [==============================] - 0s 6ms/step - loss: 488.9268 - val_loss: 499.8738
# Epoch 3/50
# 11/11 [==============================] - 0s 7ms/step - loss: 417.9966 - val_loss: 432.3005
# Epoch 4/50
# 11/11 [==============================] - 0s 7ms/step - loss: 357.9150 - val_loss: 376.7496
# Epoch 5/50
# 11/11 [==============================] - 0s 5ms/step - loss: 308.9962 - val_loss: 331.6225
# Epoch 6/50
# 11/11 [==============================] - 0s 5ms/step - loss: 269.9267 - val_loss: 295.9579
# Epoch 7/50
# 11/11 [==============================] - 0s 6ms/step - loss: 239.2881 - val_loss: 267.5493
# Epoch 8/50
# 11/11 [==============================] - 0s 5ms/step - loss: 214.9746 - val_loss: 246.2076
# Epoch 9/50
# 11/11 [==============================] - 0s 7ms/step - loss: 196.3040 - val_loss: 227.9539
# Epoch 10/50
# 11/11 [==============================] - 0s 5ms/step - loss: 181.5300 - val_loss: 214.4437
# Epoch 11/50
# 11/11 [==============================] - 0s 5ms/step - loss: 171.0110 - val_loss: 204.1865
# Epoch 12/50
# 11/11 [==============================] - 0s 5ms/step - loss: 162.7681 - val_loss: 195.9663
# Epoch 13/50
# 11/11 [==============================] - 0s 5ms/step - loss: 156.4915 - val_loss: 189.8171
# Epoch 14/50
# 11/11 [==============================] - 0s 6ms/step - loss: 151.3122 - val_loss: 184.3670
# Epoch 15/50
# 11/11 [==============================] - 0s 6ms/step - loss: 146.8368 - val_loss: 179.4769
# Epoch 16/50
# 11/11 [==============================] - 0s 6ms/step - loss: 142.8546 - val_loss: 174.5246
# Epoch 17/50
# 11/11 [==============================] - 0s 7ms/step - loss: 139.0957 - val_loss: 170.5815
# Epoch 18/50
# 11/11 [==============================] - 0s 5ms/step - loss: 135.9288 - val_loss: 167.0387
# Epoch 19/50
# 11/11 [==============================] - 0s 7ms/step - loss: 132.9884 - val_loss: 163.7687
# Epoch 20/50
# 11/11 [==============================] - 0s 5ms/step - loss: 130.0680 - val_loss: 160.3398
# Epoch 21/50
# 11/11 [==============================] - 0s 4ms/step - loss: 127.3092 - val_loss: 156.9959
# Epoch 22/50
# 11/11 [==============================] - 0s 6ms/step - loss: 124.4333 - val_loss: 153.8011
# Epoch 23/50
# 11/11 [==============================] - 0s 5ms/step - loss: 121.6272 - val_loss: 150.7460
# Epoch 24/50
# 11/11 [==============================] - 0s 5ms/step - loss: 118.9715 - val_loss: 147.8330
# Epoch 25/50
# 11/11 [==============================] - 0s 5ms/step - loss: 116.4793 - val_loss: 144.9189
# Epoch 26/50
# 11/11 [==============================] - 0s 5ms/step - loss: 113.8638 - val_loss: 141.4849
# Epoch 27/50
# 11/11 [==============================] - 0s 7ms/step - loss: 111.3363 - val_loss: 138.4185
# Epoch 28/50
# 11/11 [==============================] - 0s 6ms/step - loss: 108.8451 - val_loss: 135.5058
# Epoch 29/50
# 11/11 [==============================] - 0s 5ms/step - loss: 106.3991 - val_loss: 132.7586
# Epoch 30/50
# 11/11 [==============================] - 0s 5ms/step - loss: 104.1312 - val_loss: 130.3663
# Epoch 31/50
# 11/11 [==============================] - 0s 5ms/step - loss: 102.2194 - val_loss: 127.5253
# Epoch 32/50
# 11/11 [==============================] - 0s 5ms/step - loss: 99.9211 - val_loss: 125.2090
# Epoch 33/50
# 11/11 [==============================] - 0s 5ms/step - loss: 97.9722 - val_loss: 122.9907
# Epoch 34/50
# 11/11 [==============================] - 0s 6ms/step - loss: 96.0594 - val_loss: 120.8571
# Epoch 35/50
# 11/11 [==============================] - 0s 7ms/step - loss: 94.2208 - val_loss: 118.4280
# Epoch 36/50
# 11/11 [==============================] - 0s 5ms/step - loss: 92.2450 - val_loss: 116.2478
# Epoch 37/50
# 11/11 [==============================] - 0s 5ms/step - loss: 90.6233 - val_loss: 114.1904
# Epoch 38/50
# 11/11 [==============================] - 0s 5ms/step - loss: 88.9596 - val_loss: 112.3503
# Epoch 39/50
# 11/11 [==============================] - 0s 5ms/step - loss: 87.3384 - val_loss: 110.4680
# Epoch 40/50
# 11/11 [==============================] - 0s 5ms/step - loss: 85.8016 - val_loss: 108.4206
# Epoch 41/50
# 11/11 [==============================] - 0s 5ms/step - loss: 84.2696 - val_loss: 106.4934
# Epoch 42/50
# 11/11 [==============================] - 0s 5ms/step - loss: 82.7255 - val_loss: 104.8115
# Epoch 43/50
# 11/11 [==============================] - 0s 7ms/step - loss: 81.3635 - val_loss: 103.2412
# Epoch 44/50
# 11/11 [==============================] - 0s 7ms/step - loss: 80.0210 - val_loss: 101.5598
# Epoch 45/50
# 11/11 [==============================] - 0s 6ms/step - loss: 78.6507 - val_loss: 99.8947
# Epoch 46/50
# 11/11 [==============================] - 0s 5ms/step - loss: 77.4047 - val_loss: 98.5350
# Epoch 47/50
# 11/11 [==============================] - 0s 6ms/step - loss: 76.1929 - val_loss: 97.0454
# Epoch 48/50
# 11/11 [==============================] - 0s 6ms/step - loss: 75.0120 - val_loss: 95.6379
# Epoch 49/50
# 11/11 [==============================] - 0s 5ms/step - loss: 73.8772 - val_loss: 94.1202
# Epoch 50/50
# 11/11 [==============================] - 0s 8ms/step - loss: 72.6741 - val_loss: 92.7869

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(hist)

# %% [markdown]
# * 예측 및 평가

# %%
pred3 = model3.predict(x_val)
print(f'RMSE : {mean_squared_error(y_val, pred3, squared=False)}')
print(f'MAE  : {mean_absolute_error(y_val, pred3)}')
print(f'MAPE : {mean_absolute_percentage_error(y_val, pred3)}')
# Out:
# 4/4 [==============================] - 0s 3ms/step
# RMSE : 7.661480707146791
# MAE  : 5.218424922344731
# MAPE : 0.255004728178486

# %% [markdown]
# ----

# %% [markdown]
# ## 5.딥러닝3 : hidden layer!
# * 이제 레이어를 추가해 보겠습니다.

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 분할

# %%
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
nfeatures = x_train.shape[1] #num of columns
nfeatures

# %%
# 메모리 정리
clear_session()

# Sequential 타입 모델 선언(입력은 리스트로!)
model3 = Sequential([  Dense(2, input_shape = (nfeatures,), activation = 'relu'),
                       Dense(1)   ])

# 모델요약
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 26
#
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * compile

# %%
model3.compile( optimizer= Adam(learning_rate=0.1), loss = 'mse')

# %% [markdown]
# * 학습

# %%
hist = model3.fit(x_train, y_train, epochs = 50 , validation_split= .2 ).history

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(hist)

# %% [markdown]
# * 예측 및 평가

# %%
pred3 = model3.predict(x_val)
print(f'RMSE : {mean_squared_error(y_val, pred3, squared=False)}')
print(f'MAE  : {mean_absolute_error(y_val, pred3)}')
print(f'MAPE : {mean_absolute_percentage_error(y_val, pred3)}')
# Out:
# 4/4 [==============================] - 0s 3ms/step
# RMSE : 8.071520781287031
# MAE  : 5.562114064833698
# MAPE : 0.32532264931606725

# %% [markdown]
# ### (3) 실습1

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | Param # |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 8) | 104 |
# | dense_1 (Dense) | (None, 1) | 9 |

# %%
nfeature = x_train.shape[1]

m1 = Sequential([Dense(8, input_shape = (nfeatures, ), activation = 'relu')
                , Dense(1) ])

m1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 8)                 104
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 113
# Trainable params: 113
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * 컴파일 + 학습

# %%
m1.compile( optimizer=Adam(learning_rate=.1), loss = 'mse')
hist = m1.fit(x_train, y_train, epochs = 50 , validation_split= .2 ).history
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 16ms/step - loss: 385.9008 - val_loss: 179.7344
# Epoch 2/50
# 11/11 [==============================] - 0s 5ms/step - loss: 154.6675 - val_loss: 109.7835
# Epoch 3/50
# 11/11 [==============================] - 0s 5ms/step - loss: 84.5926 - val_loss: 60.2122
# Epoch 4/50
# 11/11 [==============================] - 0s 6ms/step - loss: 64.7916 - val_loss: 47.8497
# Epoch 5/50
# 11/11 [==============================] - 0s 6ms/step - loss: 54.9633 - val_loss: 37.5362
# Epoch 6/50
# 11/11 [==============================] - 0s 5ms/step - loss: 44.3468 - val_loss: 29.6636
# Epoch 7/50
# 11/11 [==============================] - 0s 5ms/step - loss: 36.2945 - val_loss: 23.3724
# Epoch 8/50
# 11/11 [==============================] - 0s 5ms/step - loss: 30.5913 - val_loss: 19.3660
# Epoch 9/50
# 11/11 [==============================] - 0s 5ms/step - loss: 28.9229 - val_loss: 16.1438
# Epoch 10/50
# 11/11 [==============================] - 0s 8ms/step - loss: 27.5549 - val_loss: 19.9741
# Epoch 11/50
# 11/11 [==============================] - 0s 5ms/step - loss: 24.8667 - val_loss: 14.4577
# Epoch 12/50
# 11/11 [==============================] - 0s 5ms/step - loss: 36.4289 - val_loss: 13.4252
# Epoch 13/50
# 11/11 [==============================] - 0s 7ms/step - loss: 26.6858 - val_loss: 14.8366
# Epoch 14/50
# 11/11 [==============================] - 0s 7ms/step - loss: 24.9401 - val_loss: 19.2760
# Epoch 15/50
# 11/11 [==============================] - 0s 6ms/step - loss: 24.1336 - val_loss: 12.6201
# Epoch 16/50
# 11/11 [==============================] - 0s 6ms/step - loss: 21.7962 - val_loss: 17.7099
# Epoch 17/50
# 11/11 [==============================] - 0s 6ms/step - loss: 21.6553 - val_loss: 11.9234
# Epoch 18/50
# 11/11 [==============================] - 0s 6ms/step - loss: 22.2101 - val_loss: 20.8448
# Epoch 19/50
# 11/11 [==============================] - 0s 7ms/step - loss: 23.3081 - val_loss: 15.6833
# Epoch 20/50
# 11/11 [==============================] - 0s 6ms/step - loss: 20.8667 - val_loss: 11.9048
# Epoch 21/50
# 11/11 [==============================] - 0s 7ms/step - loss: 20.8244 - val_loss: 12.9763
# Epoch 22/50
# 11/11 [==============================] - 0s 7ms/step - loss: 19.4403 - val_loss: 13.3702
# Epoch 23/50
# 11/11 [==============================] - 0s 7ms/step - loss: 19.2378 - val_loss: 12.1959
# Epoch 24/50
# 11/11 [==============================] - 0s 6ms/step - loss: 18.5652 - val_loss: 11.7693
# Epoch 25/50
# 11/11 [==============================] - 0s 6ms/step - loss: 22.1389 - val_loss: 12.4968
# Epoch 26/50
# 11/11 [==============================] - 0s 7ms/step - loss: 31.2335 - val_loss: 41.6365
# Epoch 27/50
# 11/11 [==============================] - 0s 6ms/step - loss: 25.8180 - val_loss: 16.8401
# Epoch 28/50
# 11/11 [==============================] - 0s 7ms/step - loss: 19.8581 - val_loss: 13.1196
# Epoch 29/50
# 11/11 [==============================] - 0s 7ms/step - loss: 17.2600 - val_loss: 13.2761
# Epoch 30/50
# 11/11 [==============================] - 0s 5ms/step - loss: 16.6865 - val_loss: 14.6090
# Epoch 31/50
# 11/11 [==============================] - 0s 5ms/step - loss: 15.7808 - val_loss: 13.1468
# Epoch 32/50
# 11/11 [==============================] - 0s 6ms/step - loss: 16.1967 - val_loss: 16.6214
# Epoch 33/50
# 11/11 [==============================] - 0s 6ms/step - loss: 16.2836 - val_loss: 12.4802
# Epoch 34/50
# 11/11 [==============================] - 0s 7ms/step - loss: 19.9381 - val_loss: 24.4190
# Epoch 35/50
# 11/11 [==============================] - 0s 5ms/step - loss: 17.7923 - val_loss: 14.4111
# Epoch 36/50
# 11/11 [==============================] - 0s 7ms/step - loss: 15.3710 - val_loss: 14.3753
# Epoch 37/50
# 11/11 [==============================] - 0s 7ms/step - loss: 14.9708 - val_loss: 14.2322
# Epoch 38/50
# 11/11 [==============================] - 0s 6ms/step - loss: 14.2942 - val_loss: 13.7771
# Epoch 39/50
# 11/11 [==============================] - 0s 5ms/step - loss: 13.8429 - val_loss: 12.5760
# Epoch 40/50
# 11/11 [==============================] - 0s 6ms/step - loss: 13.5265 - val_loss: 14.6832
# Epoch 41/50
# 11/11 [==============================] - 0s 6ms/step - loss: 14.0498 - val_loss: 14.6212
# Epoch 42/50
# 11/11 [==============================] - 0s 8ms/step - loss: 13.4607 - val_loss: 11.9730
# Epoch 43/50
# 11/11 [==============================] - 0s 7ms/step - loss: 13.2177 - val_loss: 13.8144
# Epoch 44/50
# 11/11 [==============================] - 0s 6ms/step - loss: 13.5561 - val_loss: 12.5843
# Epoch 45/50
# 11/11 [==============================] - 0s 6ms/step - loss: 18.3008 - val_loss: 13.0391
# Epoch 46/50
# 11/11 [==============================] - 0s 5ms/step - loss: 14.7601 - val_loss: 14.4869
# Epoch 47/50
# 11/11 [==============================] - 0s 5ms/step - loss: 12.8681 - val_loss: 12.4264
# Epoch 48/50
# 11/11 [==============================] - 0s 6ms/step - loss: 12.6676 - val_loss: 13.3774
# Epoch 49/50
# 11/11 [==============================] - 0s 7ms/step - loss: 12.6789 - val_loss: 12.0608
# Epoch 50/50
# 11/11 [==============================] - 0s 6ms/step - loss: 13.6059 - val_loss: 12.1259

# %% [markdown]
# * 학습곡선

# %%
dl_history_plot(hist)

# %% [markdown]
# * 검증

# %%
p1 = m1.predict(x_val)
print(f'RMSE : {mean_squared_error(y_val, p1, squared=False)}')
print(f'MAE  : {mean_absolute_error(y_val, p1)}')
print(f'MAPE : {mean_absolute_percentage_error(y_val, p1)}')
# Out:
# 4/4 [==============================] - 0s 5ms/step
# RMSE : 4.236956563349992
# MAE  : 3.3932462692260748
# MAPE : 0.1884874925250868

# %% [markdown]
# ### (4) 실습2

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | Param # | 옵션 |
# | ---- | ---- | ---- | ---- |
# | dense (Dense) | (None, 8) | 112 | node, input_shape, activation |
# | dense_1 (Dense) | (None, 4) | 36 | node, activation |
# | dense_2 (Dense) | (None, 1) | 5 | node |

# %%
nfeatures = x_train.shape[1]
nfeatures
# Out:
# 12

# %% [markdown]
# * 컴파일 + 학습

# %%
clear_session()

model4 = Sequential([Dense(8, input_shape = (nfeatures, ), activation = 'relu') ,
                     Dense(4, activation= 'relu'),
                     Dense(1)])

model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 104
#
#  dense_1 (Dense)             (None, 4)                 36
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# _________________________________________________________________

# %%
model4.compile( optimizer= Adam(learning_rate=0.1)  , loss = 'mse'   )

# %% [markdown]
# * 학습곡선

# %%
hist = model4.fit(x_train, y_train, epochs = 50    , validation_split = .2 ).history

# %% [markdown]
# * 검증

# %%
dl_history_plot(hist)

# %%
pred4 = model4.predict(x_val)
print(f'RMSE : {mean_squared_error(y_val, pred4, squared=False)}')
print(f'MAE  : {mean_absolute_error(y_val, pred4)}')
print(f'MAPE : {mean_absolute_percentage_error(y_val, pred4)}')
# Out:
# 4/4 [==============================] - 0s 5ms/step
# RMSE : 8.068870663922432
# MAE  : 5.554713552138385
# MAPE : 0.32462934975523666

# %% [markdown]
# ### (5) 실습3

# %% [markdown]
# * 이번에는 여러분이 원하는 대로 설계하고, 학습해 봅시다.

# %% [markdown]
# * 컴파일 + 학습

# %% [markdown]
# * 학습곡선

# %% [markdown]
# * 검증
